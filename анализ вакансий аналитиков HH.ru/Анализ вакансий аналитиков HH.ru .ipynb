# %% [markdown]
# # Анализ вакансий аналитиков HH.ru

# %% [markdown]
# # Оглавление
# 1. [Описание проекта](#cell1)
# 2. [Предобработка данных](#cell2)
# 3. [Исследовательский анализ данных](#cell3)
#
#    3.1 [Анализ требуемых ключевых навыков](#cell3.1)
#
#    3.2 [Анализ вакансий в разбивке по грейдам и регионам](#cell3.2)
#
#    3.3.[Анализ работодателей](#cell3.3)
#
#    3.4 [Анализ вакансий по формату работы и типу занятости](#cell3.4)
#
#    3.5 [Анализ уровня предлагаемой оплаты](#cell3.5)
#
# 4. [Общий вывод](#cell4)

# %% [markdown]
# <a id="cell1"></a>
# ## Описание проекта

# %% [markdown]
# **Цель проекта:**
#
# выявить различия в предлагаемых вакансиях для аналитиков данных и системных аналитиков, выявить ключевые навыки, требуемые работодателями, описать типовые параметры работодателей  (ТОП-работодателей, зарплата, тип занятости, график работы, в т.ч. в разбивке по грейдам), чтобы помочь потенциальным соискателям сориентироваться на рынке труда.
#
# **Описание данных:**
#
# данные о вакансиях за первое полугодие 2024 г., полученные из API HH.ru
#
# **План исследования:**
#
# 1. выполнить предобработку данных (проверить корректность форматов данных, выявить/обработать пропуски, дубликаты, объединить данные)
# 2. провести исследовательский анализ данных:
#
#        - выявить требуемые ключевые навыки кандидатов
#        - проанализировать вакансии в разбивке по типу занятости и формату работы, региону
#        - определить ТОП работодателей по количеству вакансий
#        - определить средние/медианные зарплаты в разбивке по грейдам
#        - сформировать типовые портреты соискателей

# %% [markdown]
# <a id="cell2"></a>
# ## 1 Предобработка данных

# %%
# импорт библиотек
import pandas as pd
from datetime import datetime, timedelta
from matplotlib import pyplot as plt
import seaborn as sns
import numpy as np

from statistics import mode
from collections import Counter
from ast import literal_eval

# %%
# выгрузка данных в датафрейм

data_analyst = pd.read_excel('vacancies_da3.xls')  # вакансии системного аналитика
system_analyst = pd.read_excel('vacancies_sa3.xls')  # вакансии  аналитика данных

# %%
# информация о датафрейме
data_analyst.info()
data_analyst.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1801 entries, 0 to 1800
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                1801 non-null   int64
#  1   name                              1801 non-null   object
#  2   published_at                      1801 non-null   datetime64[ns]
#  3   alternate_url                     1801 non-null   object
#  4   type                              1801 non-null   object
#  5   employer                          1801 non-null   object
#  6   department                        521 non-null    object
#  7   area                              1801 non-null   object
#  8   experience                        1801 non-null   object
#  9   key_skills                        1801 non-null   object
#  10  schedule                          1801 non-null   object
#  11  employment                        1801 non-null   object
#  12  description                       1801 non-null   object
#  13  description_lemmatized            1801 non-null   object
#  14  salary_from                       348 non-null    float64
#  15  salary_to                         228 non-null    float64
#  16  salary_bin                        1801 non-null   object
#  17  key_skills_from_key_skills_field  1093 non-null   object
#  18  hard_skills_from_description      418 non-null    object
#  19  soft_skills_from_description      588 non-null    object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(16)
# memory usage: 281.5+ KB
#           id                                    name        published_at  \
# 0  100039284  Junior аналитик данных (исследователь) 2024-05-24 09:37:04
# 1  100039480                         Аналитик данных 2024-05-24 09:39:00
# 2  100042705         Аналитик данных (исследователь) 2024-05-24 10:01:25
# 3  100046788                 Ведущий аналитик данных 2024-05-24 10:28:18
# 4  100056244                         Аналитик данных 2024-05-24 11:27:40
#
#                      alternate_url      type           employer  \
# 0  https://hh.ru/vacancy/100039284  Открытая  DNS Головной офис
# 1  https://hh.ru/vacancy/100039480  Открытая              Комус
# 2  https://hh.ru/vacancy/100042705  Открытая  DNS Головной офис
# 3  https://hh.ru/vacancy/100046788  Открытая           Х5 Group
# 4  https://hh.ru/vacancy/100056244  Открытая             ЛУКОЙЛ
#
#                    department         area             experience  \
# 0                         NaN  Владивосток  Junior (no experince)
# 1                         NaN       Москва  Junior (no experince)
# 2                         NaN  Владивосток    Junior+ (1-3 years)
# 3  X5 GROUP, Центральный офис       Москва    Junior+ (1-3 years)
# 4                         NaN       Москва     Middle (3-6 years)
#
#                                           key_skills     schedule  \
# 0              ['Power BI', 'СУБД', 'Python', 'SQL']  Полный день
# 1   ['MS SQL', 'Работа с базами данных', 'MS Excel']  Полный день
# 2  ['SQL', 'Power BI', 'СУБД', 'Python', 'Clickho...  Полный день
# 3  ['Анализ данных', 'Коммуникация', 'SQL', 'MS O...  Полный день
# 4                                   ['Документация']  Полный день
#
#          employment                                        description  \
# 0  Полная занятость  наше направление занимается повышением эффекти...
# 1  Полная занятость  сегодня комус один из крупнейших поставщиков о...
# 2  Полная занятость  наше направление занимается повышением эффекти...
# 3  Полная занятость  задачи:  разработка бизнес-моделей для группов...
# 4  Полная занятость  обязанности:  участие в проектировании, разраб...
#
#                               description_lemmatized  salary_from  salary_to  \
# 0  наш направление заниматься повышение эффективн...      60000.0        NaN
# 1  сегодня комус крупный поставщик офисный товар ...          NaN        NaN
# 2  наш направление заниматься повышение эффективн...      90000.0        NaN
# 3  задача разработка бизнес модель групповой прог...          NaN        NaN
# 4  обязанность участие проектирование разработка ...          NaN        NaN
#
#       salary_bin                   key_skills_from_key_skills_field  \
# 0  ЗП не указана                        SQL, Power BI, Python, СУБД
# 1  ЗП не указана           Работа с базами данных, MS SQL, MS Excel
# 2  ЗП не указана      SQL, Power BI, Python, СУБД, BPMN, Clickhouse
# 3  ЗП не указана  MS Office, SQL, Python, Hadoop, Нive, Аналитич...
# 4  ЗП не указана                                                NaN
#
#   hard_skills_from_description soft_skills_from_description
# 0                          NaN                          NaN
# 1                          NaN                          NaN
# 2                          NaN                          NaN
# 3       Pandas, Юнит-экономика                 Коммуникация
# 4                          NaN                 Документация

# %%
# информация о датафрейме
system_analyst.info()
system_analyst.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1915 entries, 0 to 1914
# Data columns (total 20 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                1915 non-null   int64
#  1   name                              1915 non-null   object
#  2   published_at                      1915 non-null   datetime64[ns]
#  3   alternate_url                     1915 non-null   object
#  4   type                              1915 non-null   object
#  5   employer                          1915 non-null   object
#  6   department                        361 non-null    object
#  7   area                              1915 non-null   object
#  8   experience                        1915 non-null   object
#  9   key_skills                        1915 non-null   object
#  10  schedule                          1915 non-null   object
#  11  employment                        1915 non-null   object
#  12  description                       1915 non-null   object
#  13  description_lemmatized            1915 non-null   object
#  14  salary_from                       356 non-null    float64
#  15  salary_to                         279 non-null    float64
#  16  salary_bin                        1915 non-null   object
#  17  key_skills_from_key_skills_field  1274 non-null   object
#  18  hard_skills_from_description      570 non-null    object
#  19  soft_skills_from_description      1427 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(16)
# memory usage: 299.3+ KB
#           id                            name        published_at  \
# 0  100046399              Системный аналитик 2024-07-08 10:22:57
# 1  100050107       Бизнес/Системный Аналитик 2024-07-06 17:19:32
# 2  100059559           Системный IT аналитик 2024-07-08 11:48:17
# 3  100063260  Системный Аналитик ERP-решений 2024-07-09 10:51:54
# 4  100064793              Системный аналитик 2024-07-08 16:39:40
#
#                      alternate_url      type           employer department  \
# 0  https://hh.ru/vacancy/100046399  Открытая              Юрент        NaN
# 1  https://hh.ru/vacancy/100050107  Открытая               Surf        NaN
# 2  https://hh.ru/vacancy/100059559  Открытая           AMarkets        NaN
# 3  https://hh.ru/vacancy/100063260  Открытая              Астор        NaN
# 4  https://hh.ru/vacancy/100064793  Открытая  Зетта Страхование        NaN
#
#               area           experience  \
# 0           Москва   Middle (3-6 years)
# 1  Санкт-Петербург  Junior+ (1-3 years)
# 2           Москва  Junior+ (1-3 years)
# 3           Москва    Senior (6+ years)
# 4           Москва  Junior+ (1-3 years)
#
#                                           key_skills          schedule  \
# 0  ['1С', 'Аналитический склад ума', 'confluence'...       Полный день
# 1  ['Разработка технических заданий', 'Бизнес-ана...  Удаленная работа
# 2                                   ['Документация']       Полный день
# 3  ['ERP', 'Atlassian Jira', '1С: Управление Прои...  Удаленная работа
# 4  ['JSON', 'SQL', 'XML', 'SOAP', 'HTML', 'JS', '...       Полный день
#
#          employment                                        description  \
# 0  Полная занятость  юрент — это новый уровень городской мобильност...
# 1  Полная занятость  в surf уже 13 лет мы разрабатываем много разны...
# 2  Полная занятость  мы - международная fintech компания amarkets, ...
# 3  Полная занятость  компания «астор» с 2000 года занимается разраб...
# 4  Полная занятость  обязанности:   анализ задач развития и сопрово...
#
#                               description_lemmatized  salary_from  salary_to  \
# 0  юрент новый уровень городской мобильность круп...          NaN        NaN
# 1  surf 13 год разрабатывать разный продукт начин...          NaN        NaN
# 2  международный fintech компания amarkets 2 7 го...     233750.0        NaN
# 3  компания астор 2 год заниматься разработка вне...          NaN        NaN
# 4  обязанность анализ задача развитие сопровожден...          NaN        NaN
#
#       salary_bin                   key_skills_from_key_skills_field  \
# 0  ЗП не указана                   SQL, Аналитический склад ума, 1С
# 1  ЗП не указана  BPMN, UML, Английский язык, Системный анализ, ...
# 2  ЗП не указана                                                NaN
# 3  ЗП не указана  ERP, 1С: Управление Торговлей, Atlassian Jira,...
# 4  ЗП не указана      SQL, C#, Java, JS, SOAP, JSON, XML, HTML, CSS
#
#   hard_skills_from_description soft_skills_from_description
# 0                   confluence                          NaN
# 1                          NaN                 Документация
# 2                          NaN                 Документация
# 3                   confluence                 Коммуникация
# 4                          NaN                          NaN

# %%
# объединяем данные в один датасет
data_analyst['profession_type'] = 'data_analyst'
system_analyst['profession_type'] = 'system_analyst'
hh_data = pd.concat([data_analyst, system_analyst], ignore_index=True)
hh_data.info()
hh_data.sample(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3716 entries, 0 to 3715
# Data columns (total 21 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   id                                3716 non-null   int64
#  1   name                              3716 non-null   object
#  2   published_at                      3716 non-null   datetime64[ns]
#  3   alternate_url                     3716 non-null   object
#  4   type                              3716 non-null   object
#  5   employer                          3716 non-null   object
#  6   department                        882 non-null    object
#  7   area                              3716 non-null   object
#  8   experience                        3716 non-null   object
#  9   key_skills                        3716 non-null   object
#  10  schedule                          3716 non-null   object
#  11  employment                        3716 non-null   object
#  12  description                       3716 non-null   object
#  13  description_lemmatized            3716 non-null   object
#  14  salary_from                       704 non-null    float64
#  15  salary_to                         507 non-null    float64
#  16  salary_bin                        3716 non-null   object
#  17  key_skills_from_key_skills_field  2367 non-null   object
#  18  hard_skills_from_description      988 non-null    object
#  19  soft_skills_from_description      2015 non-null   object
#  20  profession_type                   3716 non-null   object
# dtypes: datetime64[ns](1), float64(2), int64(1), object(17)
# memory usage: 609.8+ KB
#              id                                             name  \
# 3138   52410283                            Системный аналитик 1С
# 2224  102459625  Системный аналитик / Project manager (удаленно)
# 30    100261906                         Аналитик данных (Python)
# 2962  103471811        Системный аналитик (мобильные приложения)
# 1460   98428661                                  Аналитик данных
#
#             published_at                    alternate_url      type  \
# 3138 2024-07-08 13:56:18   https://hh.ru/vacancy/52410283  Открытая
# 2224 2024-07-06 20:56:51  https://hh.ru/vacancy/102459625  Открытая
# 30   2024-05-27 01:56:59  https://hh.ru/vacancy/100261906  Открытая
# 2962 2024-07-08 09:07:41  https://hh.ru/vacancy/103471811  Открытая
# 1460 2024-05-06 07:58:55   https://hh.ru/vacancy/98428661  Открытая
#
#                                    employer department          area  \
# 3138       Диалог Информационные Технологии        NaN  Екатеринбург
# 2224            Андреев Артём Александрович        NaN        Москва
# 30    Центральный банк Российской Федерации        NaN        Москва
# 2962                        РНКБ Банк (ПАО)        NaN        Москва
# 1460                           Медикал Скул        NaN        Москва
#
#                  experience  \
# 3138    Junior+ (1-3 years)
# 2224     Middle (3-6 years)
# 30      Junior+ (1-3 years)
# 2962      Senior (6+ years)
# 1460  Junior (no experince)
#
#                                              key_skills  ...  \
# 3138  ['Бизнес-анализ', 'Моделирование бизнес процес...  ...
# 2224                                   ['Документация']  ...
# 30                    ['SQL-запросы', 'JIRA', 'Python']  ...
# 2962  ['iOS', 'Мобильные приложения', 'Разработка те...  ...
# 1460                         ['Аналитическое мышление']  ...
#
#             employment                                        description  \
# 3138  Полная занятость  «диалог ит» — российская аккредитованная it-ко...
# 2224  Полная занятость  бьюти бот - это инновационный ит-продукт, what...
# 30    Полная занятость  задачи:  анализ требований структурных подразд...
# 2962  Полная занятость  рнкб – ключевой банк республики крым. также пр...
# 1460  Полная занятость  md.school — это онлайн-университет доказательн...
#
#                                  description_lemmatized salary_from  \
# 3138  диалог ита российский аккредитовать it компани...         NaN
# 2224  бьютя бот инновационный ита продукт whatsapp б...         NaN
# 30    задача анализ требование структурный подраздел...         NaN
# 2962  рнкб ключевой банк республика крым также предс...         NaN
# 1460  md school онлайн университет доказательный мед...         NaN
#
#       salary_to     salary_bin  \
# 3138        NaN  ЗП не указана
# 2224        NaN  ЗП не указана
# 30          NaN  ЗП не указана
# 2962        NaN  ЗП не указана
# 1460        NaN  ЗП не указана
#
#                        key_skills_from_key_skills_field  \
# 3138  1С: Предприятие 8, Моделирование бизнес процес...
# 2224                                                NaN
# 30                            JIRA, Python, SQL-запросы
# 2962  BPMN, Разработка технических заданий, Системны...
# 1460                                                NaN
#
#      hard_skills_from_description soft_skills_from_description profession_type
# 3138                          NaN                 Документация  system_analyst
# 2224                          NaN                 Документация  system_analyst
# 30                            NaN                          NaN    data_analyst
# 2962                   confluence                 Документация  system_analyst
# 1460                          NaN       Аналитическое мышление    data_analyst
#
# [5 rows x 21 columns]

# %%
# количество пропусков
hh_data.isna().sum()
# Out:
# id                                     0
# name                                   0
# published_at                           0
# alternate_url                          0
# type                                   0
# employer                               0
# department                          2834
# area                                   0
# experience                             0
# key_skills                             0
# schedule                               0
# employment                             0
# description                            0
# description_lemmatized                 0
# salary_from                         3012
# salary_to                           3209
# salary_bin                             0
# key_skills_from_key_skills_field    1349
# hard_skills_from_description        2728
# soft_skills_from_description        1701
# profession_type                        0
# dtype: int64

# %%
#проверяем значения ключевых столбцов, в т.ч. на наличие неявных дубликатов
print(hh_data['type'].unique())
print(hh_data['area'].unique())
print(hh_data['experience'].unique())
print(hh_data['schedule'].unique())
print(hh_data['employment'].unique())
print(hh_data['profession_type'].unique())
# Out:
# ['Открытая']
# ['Владивосток' 'Москва' 'Санкт-Петербург' 'Казань' 'Екатеринбург'
#  'Смоленск' 'Новосибирск' 'Омск' 'Краснодар' 'Самара' 'Уфа' 'Нефтекамск'
#  'Курган' 'Пермь' 'Ростов-на-Дону' 'Нижний Новгород' 'Чебоксары'
#  'Владимир' 'Воронеж' 'Адыгейск' 'Тверь' 'Балашиха'
#  'Киров (Кировская область)' 'Калининград' 'Тюмень' 'Челябинск' 'Майкоп'
#  'Липецк' 'Красноярск' 'Горно-Алтайск' 'Дзержинский' 'Белгород' 'Ступино'
#  'Рязань' 'Томск' 'Северск (Томская область)' 'Артем' 'Верхняя Пышма'
#  'Щербинка' 'Кемерово' 'Подольск (Московская область)' 'Королев' 'Ижевск'
#  'Вейделевка' 'Химки' 'Ульяновск' 'Иваново (Ивановская область)'
#  'Луховицы' 'Златоуст' 'Набережные Челны' 'Байбек' 'Иркутск' 'Турочак'
#  'Симферополь' 'Вельск' 'Алтайское' 'Сочи' 'Саратов' 'Оренбург' 'Псков'
#  'Великие Луки' 'Магнитогорск' 'Пушкино (Московская область)' 'Мытищи'
#  'Тула' 'Тольятти' 'Волгоград' 'Дмитров' 'Якутск' 'Одинцово' 'Апатиты'
#  'Курск' 'Геленджик' 'Рубцовск' 'Кольчугино' 'Калуга' 'Кострома' 'Пенза'
#  'Ставрополь' 'Хасавюрт' 'Вологда' 'Йошкар-Ола' 'Тамбов' 'Орел'
#  'Красногорск' 'Сургут' 'Белорецк' 'Ярославль' 'Брянск' 'Адлер' 'Саранск'
#  'Севастополь' 'Дзержинск (Нижегородская область)' 'Иннополис' 'Хабаровск'
#  'Таганрог' 'Улан-Удэ' 'Петрозаводск' 'Барнаул' 'Астрахань' 'Муром'
#  'Новочеркасск' 'Дубна' 'Череповец' 'Новокузнецк' 'Абакан']
# ['Junior (no experince)' 'Junior+ (1-3 years)' 'Middle (3-6 years)'
#  'Senior (6+ years)']
# ['Полный день' 'Удаленная работа' 'Гибкий график' 'Сменный график']
# ['Полная занятость' 'Стажировка' 'Частичная занятость' 'Проектная работа']
# ['data_analyst' 'system_analyst']

# %% [markdown]
# <div style="border:solid green 1px; padding: 10px">
# Вывод:
#
# - форматы данных корректны, соответствуют полям.
# - имеется большое количество пропусков в полях: department, salary_from, salary_to,  key_skills_from_key_skills_field. Пропуски будут при необходимости обработаны на следующих этапах. На данном этапе остаются без изменений.
# - нет дубликатов, в т.ч. неявных в ключевых полях, поля корректно заполнены

# %% [markdown]
# <a id="cell3"></a>
# ## Исследовательский анализ данных

# %% [markdown]
# <a id="cell3.1"></a>
# ### Анализ требуемых ключевых навыков

# %% [markdown]
# Определим наиболее востребованные ключевые навыки для кандидатов обоих типов вакансий (дата-аналитик и системный аналитик)

# %%
# проверяем значения поля key_skills 
hh_data[['key_skills']].values
# Out:
# array([["['Power BI', 'СУБД', 'Python', 'SQL']"],
#        ["['MS SQL', 'Работа с базами данных', 'MS Excel']"],
#        ["['SQL', 'Power BI', 'СУБД', 'Python', 'Clickhouse', 'BPMN']"],
#        ...,
#        ['[]'],
#        ["['SOA', 'XML', 'Atlassian Jira', 'Use cases', 'DB2', 'BPMN', 'API', 'Базы данных', 'JSON', 'IDEF', 'ORACLE', 'REST', 'SOAP', 'UML', 'WSDL', 'Xsd', 'SQL', 'System Analysis', 'User Story', 'NoSQL', 'confluence', 'Agile Project Management', 'PostgreSQL', 'Системный анализ']"],
#        ["['Документация', '1С: Предприятие', '1С: Бит Финанс', 'MS Project', 'MS Excel']"]],
#       dtype=object)

# %% [markdown]
# В поле key_skills много лишних символов, следует очистить данные перед дальнейшей обработкой

# %%
# из данных в key_skills удалим скобки и лишние кавычки, приведем к нижнему регистру и разделим по запятым, чтобы строку превратить в список
hh_data['key_skills'] = hh_data['key_skills'].str.replace("\[|\]|\'",'', regex=True).str.lower().str.split(',')
hh_data['key_skills']
# Out:
# 0                        [power bi,  субд,  python,  sql]
# 1            [ms sql,  работа с базами данных,  ms excel]
# 2       [sql,  power bi,  субд,  python,  clickhouse, ...
# 3       [анализ данных,  коммуникация,  sql,  ms offic...
# 4                                          [документация]
#                               ...
# 3711                        [документация,  коммуникация]
# 3712    [idef,  разработка технических заданий,  rest,...
# 3713                                                   []
# 3714    [soa,  xml,  atlassian jira,  use cases,  db2,...
# 3715    [документация,  1с: предприятие,  1с: бит фина...
# Name: key_skills, Length: 3716, dtype: object

# %%
# создадим новую строку для каждого элемента списка в столбце
hh_data['key_skills'].explode().str.strip()
# Out:
# 0              power bi
# 0                  субд
# 0                python
# 0                   sql
# 1                ms sql
#              ...
# 3715       документация
# 3715    1с: предприятие
# 3715     1с: бит финанс
# 3715         ms project
# 3715           ms excel
# Name: key_skills, Length: 20568, dtype: object

# %%
# испольуем Counter, чтобы посчитать частоту навыков 
skills = Counter(hh_data['key_skills'].explode().str.strip().sort_values())
skills
# Out:
# Counter({'документация': 1571,
#          'sql': 1438,
#          'confluence': 699,
#          'аналитическое мышление': 658,
#          'bpmn': 656,
#          'python': 629,
#          'системный анализ': 576,
#          'uml': 574,
#          '': 512,
#          'анализ данных': 487,
#          'коммуникация': 461,
#          'rest': 394,
#          'pandas': 330,
#          'работа с базами данных': 267,
#          'soap': 266,
#          'аналитика': 264,
#          'разработка технических заданий': 253,
#          'работа с большим объемом информации': 233,
#          'power bi': 231,
#          'бизнес-анализ': 227,
#          'ms excel': 226,
#          'постановка задач разработчикам': 216,
#          'базы данных': 215,
#          'ms sql': 212,
#          'xml': 212,
#          'api': 192,
#          'postgresql': 181,
#          'atlassian jira': 159,
#          'json': 152,
#          'atlassian confluence': 138,
#          'data analysis': 131,
#          'сбор и анализ информации': 128,
#          'аналитические исследования': 123,
#          'json api': 119,
#          'математическая статистика': 111,
#          'проактивность': 105,
#          'kafka': 97,
#          'tableau': 95,
#          'моделирование бизнес процессов': 91,
#          'rest api': 87,
#          'scrum': 86,
#          'dwh': 84,
#          'etl': 78,
#          'английский язык': 77,
#          'анализ бизнес показателей': 75,
#          'оптимизация бизнес-процессов': 74,
#          'статистический анализ': 72,
#          'системная интеграция': 69,
#          'ms powerpoint': 67,
#          'agile': 65,
#          'техническая документация': 65,
#          'big data': 63,
#          'a/b тесты': 60,
#          'git': 56,
#          'xsd': 56,
#          'субд': 56,
#          'переговоры': 54,
#          'прогнозирование': 54,
#          'работа в команде': 53,
#          'юнит-экономика': 52,
#          'hadoop': 50,
#          'сводные таблицы': 50,
#          'oracle': 49,
#          'postman': 49,
#          'деловая коммуникация': 48,
#          'clickhouse': 47,
#          'rabbitmq': 46,
#          'аналитический склад ума': 46,
#          'системное мышление': 45,
#          'agile project management': 44,
#          'ms visio': 43,
#          'математический анализ': 42,
#          'анализ требований': 41,
#          'erp-системы на базе 1с': 40,
#          'подготовка презентаций': 40,
#          'airflow': 39,
#          'ms power bi': 37,
#          'swagger': 36,
#          'system analysis': 33,
#          'vba': 33,
#          'информационные технологии': 33,
#          'apache kafka': 32,
#          'bi': 32,
#          'spark': 32,
#          'анализ рынка': 32,
#          'управление проектами': 32,
#          'автоматизация процессов': 31,
#          'проектная документация': 31,
#          'тестирование': 31,
#          'numpy': 30,
#          'java': 29,
#          '1с': 28,
#          'greenplum': 28,
#          'http': 28,
#          'jira': 28,
#          'power query': 28,
#          'powerbi': 28,
#          'user story': 28,
#          'business analysis': 27,
#          'визуализация данных': 27,
#          'разработка по': 27,
#          'excel': 26,
#          'аналитические способности': 26,
#          'креативность': 26,
#          '1с: предприятие 8': 25,
#          'сбор требований': 25,
#          '1с: управление торговлей': 24,
#          'подготовка отчетов': 24,
#          'системный подход': 24,
#          '1с: предприятие': 22,
#          'linux': 22,
#          'use case analysis': 22,
#          'описание бизнес-процессов': 22,
#          'организаторские навыки': 22,
#          'обучение и развитие': 21,
#          'machine learning': 20,
#          'ответственность': 20,
#          'dax': 19,
#          '1с: зарплата и управление персоналом': 18,
#          'data science': 18,
#          'javascript': 18,
#          'mysql': 18,
#          'грамотная речь': 18,
#          'маркетинговый анализ': 18,
#          'idef': 17,
#          'ml': 17,
#          'разработка инструкций': 17,
#          'разработка проектной документации': 17,
#          '1с программирование': 16,
#          'google analytics': 16,
#          'oracle pl/sql': 16,
#          'superset': 16,
#          'экономический анализ': 16,
#          '1с: документооборот': 15,
#          'html': 15,
#          'mq': 15,
#          'nosql': 15,
#          'r': 15,
#          'анализ бизнес-процессов': 15,
#          'деловая переписка': 15,
#          'математическое моделирование': 15,
#          '1с: управление производственным предприятием': 14,
#          'figma': 14,
#          'аналитика продаж': 14,
#          'микросервисная архитектура': 14,
#          'crm': 13,
#          'docker': 13,
#          'grafana': 13,
#          'power pivot': 13,
#          'pytorch': 13,
#          'qlik sense': 13,
#          'ui': 13,
#          'waterfall': 13,
#          'бухгалтерский учет': 13,
#          'навыки презентации': 13,
#          'торговая площадка': 13,
#          'управленческая отчетность': 13,
#          'финансовый анализ': 13,
#          'datalens': 12,
#          'draw.io': 12,
#          'kanban': 12,
#          'написание тз': 12,
#          'работа с системами аналитики': 12,
#          'складская логистика': 12,
#          'ad hoc analysis': 11,
#          'erp': 11,
#          'hive': 11,
#          'mongodb': 11,
#          'ms office': 11,
#          'openapi': 11,
#          'teradata': 11,
#          'use cases': 11,
#          'wms': 11,
#          'витрины данных': 11,
#          'впр': 11,
#          'документирование бизнес-требований': 11,
#          'управление требованиями': 11,
#          'camunda': 10,
#          'erd': 10,
#          'google docs': 10,
#          'soa': 10,
#          'ui/ux': 10,
#          'web аналитика': 10,
#          'wsdl': 10,
#          'анализ рисков': 10,
#          'аналитика данных': 10,
#          'интеграции': 10,
#          'критическое мышление': 10,
#          'навыки составления отчетности': 10,
#          'наставничество': 10,
#          'оптимизация бизнес процессов': 10,
#          'пользователь пк': 10,
#          'проектирование баз данных': 10,
#          'статистика': 10,
#          'точность и внимательность к деталям': 10,
#          'удаленная работа': 10,
#          'умение принимать решения': 10,
#          'управление командой': 10,
#          'android': 9,
#          'c#': 9,
#          'data base': 9,
#          'node.js': 9,
#          'plantuml': 9,
#          'retail': 9,
#          'анализ ассортиментной линейки': 9,
#          'бизнес-консультирование': 9,
#          'веб-программирование': 9,
#          'жизненный цикл по': 9,
#          'коммуникабельность': 9,
#          'навыки переговоров': 9,
#          'проведение презентаций': 9,
#          'проведение тестирований': 9,
#          'проектный менеджмент': 9,
#          'яндекс.метрика': 9,
#          'data analyst': 8,
#          'erp systems': 8,
#          'finebi': 8,
#          'ms access': 8,
#          'ms project': 8,
#          'ms sql server': 8,
#          'nlp': 8,
#          'pl/sql': 8,
#          'pyspark': 8,
#          'scipy': 8,
#          'soapui': 8,
#          'visio': 8,
#          'автоматизация': 8,
#          'высшее образование': 8,
#          'информационная безопасность': 8,
#          'машинное обучение': 8,
#          'моделирование процессов': 8,
#          'написание технических заданий': 8,
#          'техническое задание': 8,
#          'финансовая отчетность': 8,
#          '1с erp': 7,
#          '1с-битрикс': 7,
#          'apache airflow': 7,
#          'data mining': 7,
#          'idef0': 7,
#          'kubernetes': 7,
#          'ltv': 7,
#          'matplotlib': 7,
#          'ms outlook': 7,
#          'php': 7,
#          'scikit-learn': 7,
#          'seaborn': 7,
#          'xpath': 7,
#          'аналитические навыки': 7,
#          'гост': 7,
#          'менеджмент': 7,
#          'модели данных': 7,
#          'ориентация на результат': 7,
#          'планирование': 7,
#          'работа в условиях многозадачности': 7,
#          'разработка проектных документов': 7,
#          'разработка регламентов': 7,
#          'разработка функциональных требований': 7,
#          'умение работать в коллективе': 7,
#          'функциональное тестирование': 7,
#          '1с: управление холдингом': 6,
#          'ad-hoc': 6,
#          'archimate': 6,
#          'bigquery': 6,
#          'bpml': 6,
#          'comunda': 6,
#          'data scientist': 6,
#          'db2': 6,
#          'epc': 6,
#          'gitlab': 6,
#          'google sheets': 6,
#          'grp': 6,
#          'grpc': 6,
#          'ios': 6,
#          'it': 6,
#          'knime': 6,
#          'metabase': 6,
#          'miro': 6,
#          'qlikview': 6,
#          'redis': 6,
#          'redmine': 6,
#          'sklearn': 6,
#          'web': 6,
#          'адаптивность': 6,
#          'анализ продаж': 6,
#          'аудит': 6,
#          'битрикс24': 6,
#          'деловое общение': 6,
#          'доброжелательность': 6,
#          'инициативность и лидерство': 6,
#          'интеграция': 6,
#          'коммуникативная гибкость': 6,
#          'конкурентная аналитика': 6,
#          'макросы': 6,
#          'многозадачность': 6,
#          'ооп': 6,
#          'проектирование ис': 6,
#          'разработка технической документации': 6,
#          'решение проблем': 6,
#          'системность мышления': 6,
#          'способность к саморазвитию': 6,
#          'теория вероятности': 6,
#          'ценные бумаги': 6,
#          '1с: бухгалтерия': 5,
#          '1с: торговля': 5,
#          'apache superset': 5,
#          'cистемы управления базами данных': 5,
#          'enterprise architect': 5,
#          'google data studio': 5,
#          'informatica': 5,
#          'jupiter': 5,
#          'llm': 5,
#          'qlik': 5,
#          'terrasoft crm': 5,
#          'use case': 5,
#          'ux': 5,
#          'vertica': 5,
#          'youtrack': 5,
#          'анализ текущих финансовых показателей': 5,
#          'аналитик данных': 5,
#          'веб-аналитика': 5,
#          'ведение отчетности': 5,
#          'грамотность': 5,
#          'маркетплейс': 5,
#          'оценка рисков': 5,
#          'принятие решений': 5,
#          'продвинутый пользователь пк': 5,
#          'проектирование пользовательских интерфейсов': 5,
#          'разработка нового продукта': 5,
#          'тайм-менеджмент': 5,
#          'хранилища данных': 5,
#          'цфт': 5,
#          '1c': 4,
#          '1с: комплексная автоматизация': 4,
#          'apache spark': 4,
#          'appsflyer': 4,
#          'bash': 4,
#          'bigdata': 4,
#          'c++': 4,
#          'c4': 4,
#          'css': 4,
#          'datavault': 4,
#          'e-commerce': 4,
#          'esb': 4,
#          'http запросы': 4,
#          'olap': 4,
#          'project management': 4,
#          'sas': 4,
#          'sql запросы': 4,
#          'tensorflow': 4,
#          'автоматизация бизнес-процессов': 4,
#          'алгоритмы': 4,
#          'амбициозность': 4,
#          'анализ конкурентной среды': 4,
#          'анализ ценообразования': 4,
#          'внимание к деталям': 4,
#          'внутренний контроль': 4,
#          'гост 19': 4,
#          'госты': 4,
#          'грамотная речь и письмо': 4,
#          'исследования рынка': 4,
#          'ит': 4,
#          'клиент-серверная архитектура': 4,
#          'коммерция': 4,
#          'корпоративное хранилище данных': 4,
#          'кредитные риски': 4,
#          'мониторинг рынка': 4,
#          'обновление конфигурации 1с': 4,
#          'оптимизация логистических процессов': 4,
#          'отчетность': 4,
#          'планирование продаж': 4,
#          'портфельные риски': 4,
#          'проведение экспериментов': 4,
#          'работа с требованиями': 4,
#          'системная аналитика': 4,
#          'смэв': 4,
#          'составление отчетности': 4,
#          'стратегическое мышление': 4,
#          'стрессоустойчивость': 4,
#          'транспортная логистика': 4,
#          'управление бизнес процессами': 4,
#          'управленческий учет': 4,
#          'финансовое планирование': 4,
#          '.net core': 3,
#          '1с: erp управление предприятием': 3,
#          '1с: торговля и склад': 3,
#          '1с: фгис меркурий': 3,
#          '1с:тоир': 3,
#          'a/b тестирование': 3,
#          'access': 3,
#          'altova xml spy': 3,
#          'aris': 3,
#          'babok': 3,
#          'bi аналитика': 3,
#          'bitrix24': 3,
#          'bpmsoft': 3,
#          'business intelligence systems': 3,
#          'data engineer': 3,
#          'data vault': 3,
#          'dbeaver': 3,
#          'dbt': 3,
#          'deep learning': 3,
#          'django framework': 3,
#          'elasticsearch': 3,
#          'fork': 3,
#          'gexcel': 3,
#          'google таблицы': 3,
#          'graphql': 3,
#          'internet': 3,
#          'itsm': 3,
#          'ldap': 3,
#          'loginom': 3,
#          'low-code': 3,
#          'mdm': 3,
#          'mes': 3,
#          'ms dynamics crm': 3,
#          'ms navision': 3,
#          'olap (online analytical processing)': 3,
#          'opencv': 3,
#          'oracle bi': 3,
#          'oracle db': 3,
#          'oracle exadata': 3,
#          'oracle siebel crm': 3,
#          'pl/pgsql': 3,
#          'plotly': 3,
#          'postgesql': 3,
#          'power point': 3,
#          'powershell': 3,
#          'qlicksense': 3,
#          'rest/soap': 3,
#          'sap': 3,
#          'sharepoint': 3,
#          'specifications': 3,
#          'sql-запросы': 3,
#          'streamlit': 3,
#          'tcp/ip': 3,
#          'transformers': 3,
#          'uat': 3,
#          'user stories': 3,
#          'visiology': 3,
#          'yaml': 3,
#          'асу': 3,
#          'асу тп': 3,
#          'база данных: olap': 3,
#          'база данных: oracle': 3,
#          'бизнес-моделирование': 3,
#          'дашборды': 3,
#          'документирование': 3,
#          'закупки': 3,
#          'знание excel': 3,
#          'знание информационной системы 1с унф': 3,
#          'инвестиции': 3,
#          'клиентоориентированность': 3,
#          'логистика': 3,
#          'логическое мышление': 3,
#          'маркетинговые исследования': 3,
#          'маркетплейсы': 3,
#          'математический склад ума': 3,
#          'микросервисы': 3,
#          'моделирование': 3,
#          'моделирование бизнес-процессов': 3,
#          'мониторинг цен': 3,
#          'мсфо': 3,
#          'оптимизация 1с: ух': 3,
#          'основы баз данных': 3,
#          'поиск информации в интернет': 3,
#          'презентация результатов': 3,
#          'работа с документами': 3,
#          'работа с тмц': 3,
#          'разработка бизнес-требований': 3,
#          'реинжиниринг бизнес-процессов': 3,
#          'руководство коллективом': 3,
#          'системный аналитик': 3,
#          'складской документооборот': 3,
#          'складской учет': 3,
#          'сопровождение 1с': 3,
#          'сопровождение 1с: ух': 3,
#          'тестирование разработанного функционала': 3,
#          'умение работать в команде': 3,
#          'управление процессами': 3,
#          'участие в проектах внедрения/развития систем': 3,
#          'учет остатков': 3,
#          'учет тмц': 3,
#          'финансовый менеджмент': 3,
#          'функциональные требования': 3,
#          'цфт-банк': 3,
#          '.net': 2,
#          '.net framework': 2,
#          '1c: erp': 2,
#          '1c: предприятие': 2,
#          '1с бп': 2,
#          '1с: erp': 2,
#          '1с: предприятие: управление строительной организацией': 2,
#          '1с: розница': 2,
#          '3gpp': 2,
#          'ab-test': 2,
#          'acid': 2,
#          'alation': 2,
#          'alm': 2,
#          'alteryx': 2,
#          'analysis': 2,
#          'analytical skills': 2,
#          'anaplan': 2,
#          'arcgis': 2,
#          'architecture analyst': 2,
#          'arduino': 2,
#          'arenadata': 2,
#          'artemismq': 2,
#          'aso-кубы': 2,
#          'axapta': 2,
#          'balsamiq': 2,
#          'base station subsystem': 2,
#          'bi apache superset': 2,
#          'bi-инструменты': 2,
#          'bi-отчетность': 2,
#          'black box testing': 2,
#          'bokeh': 2,
#          'bpmn 2.0': 2,
#          'c4 diagram': 2,
#          'ci/cd': 2,
#          'cjm': 2,
#          'computer vision': 2,
#          'creatio': 2,
#          'data management': 2,
#          'data warehousing': 2,
#          'datalense': 2,
#          'devops': 2,
#          'diasoft': 2,
#          'dwh lead': 2,
#          'eda': 2,
#          'elma': 2,
#          'exasol': 2,
#          'fastapi': 2,
#          'fsd': 2,
#          'functional list/matrix': 2,
#          'gis': 2,
#          'google tag manager': 2,
#          'gsm': 2,
#          'hr': 2,
#          'idef3': 2,
#          'information security': 2,
#          'iot': 2,
#          'ipc': 2,
#          'itil': 2,
#          'js': 2,
#          'json/xml/xslt': 2,
#          'jupyter notebook': 2,
#          'kibana': 2,
#          'lan': 2,
#          'lte': 2,
#          'mashine learning': 2,
#          'meta данные': 2,
#          'mockup': 2,
#          'mssql': 2,
#          'navision business central': 2,
#          'nginx': 2,
#          'nifi': 2,
#          'openmetadata': 2,
#          'openshift': 2,
#          'optimacros': 2,
#          'oracle hyperion': 2,
#          'orm': 2,
#          'phyton': 2,
#          'polars': 2,
#          'posgresql': 2,
#          'postgres': 2,
#          'powerdesigner': 2,
#          'pr': 2,
#          'product analytics': 2,
#          'product management': 2,
#          'programmatic': 2,
#          'qgis': 2,
#          'r-keeper': 2,
#          'rabbit.mq': 2,
#          'raspberry pi': 2,
#          'react': 2,
#          'redash': 2,
#          'rtb': 2,
#          'rwa': 2,
#          'saas': 2,
#          'safe': 2,
#          'scada': 2,
#          'serm': 2,
#          'shell scripting': 2,
#          'siem': 2,
#          'spss': 2,
#          'sqlite': 2,
#          'system analyst': 2,
#          'transact-sql': 2,
#          'usecase': 2,
#          'user flow': 2,
#          'userstory': 2,
#          'v-model': 2,
#          'xml/xslt': 2,
#          'администрирование серверов': 2,
#          'анализ абс': 2,
#          'анализ временных рядов': 2,
#          'анализ финансовых показателей': 2,
#          'аналитика закупок': 2,
#          'анаплан': 2,
#          'архитектура': 2,
#          'ассортиментная матрица': 2,
#          'бюджетирование': 2,
#          'ведение документации': 2,
#          'ведение клиентской базы': 2,
#          'ведение переписки': 2,
#          'взаимодействие с заказчиком': 2,
#          'взаимодействие с разработчиками 1с': 2,
#          'визуализация': 2,
#          'внедрение информационных систем': 2,
#          'внедрение систем информационной безопасности': 2,
#          'внимательность': 2,
#          'внутренний аудит информационных систем': 2,
#          'выборка': 2,
#          'гис': 2,
#          'гост 34': 2,
#          'дашборд': 2,
#          'девелопмент': 2,
#          'депозиты': 2,
#          'заведения данных в 1с': 2,
#          'знание ms office': 2,
#          'исполнение поручений руководителя': 2,
#          'исследовательский анализ данных': 2,
#          'ит-архитектура': 2,
#          'контент-анализ': 2,
#          'корпоративная этика': 2,
#          'кредиты': 2,
#          'кхд': 2,
#          'логика': 2,
#          'маркетинг': 2,
#          'маркетинговая аналитика': 2,
#          'математика': 2,
#          'мобильное приложение': 2,
#          'мой склад': 2,
#          'мс excel': 2,
#          'нive': 2,
#          'настройка сетевых подключений': 2,
#          'настройка учетных систем': 2,
#          'нейросети': 2,
#          'нси': 2,
#          'оптимакрос': 2,
#          'оптимизация запросов': 2,
#          'опыт документирования': 2,
#          'опытный пользователь пк': 2,
#          'организация совещаний': 2,
#          'основы sql': 2,
#          'основы программирования': 2,
#          'ответственность и пунктуальность': 2,
#          'отчеты': 2,
#          'офисные программы': 2,
#          'план-фактный анализ бюджета': 2,
#          'подбор контента': 2,
#          'понимание cdc': 2,
#          'понимание etl': 2,
#          'построение хранилищ данных': 2,
#          'преподаватель': 2,
#          'проведение опросов': 2,
#          'продвинутый пользователь ms excel': 2,
#          'продуктовая аналитика': 2,
#          'продуктовые метрики': 2,
#          'проектирование': 2,
#          'проектирование по': 2,
#          'протоколирование': 2,
#          'работа в режиме многозадачности': 2,
#          'работа с выставленными счетами в 1с': 2,
#          'работа со сми': 2,
#          'разработка лекарств': 2,
#          'разработка нефункциональных требований': 2,
#          'расстановка приоритетов': 2,
#          'расчет заработной платы': 2,
#          'реклама': 2,
#          'реляционные базы данных': 2,
#          'розничная торговля': 2,
#          'рсбу': 2,
#          'руководство командой': 2,
#          'русский язык': 2,
#          'с#': 2,
#          'системность': 2,
#          'создание конфигурации 1с': 2,
#          'составление технических заданий': 2,
#          'спецификация требований': 2,
#          'строительство': 2,
#          'структуры данных': 2,
#          'терминалы сбора данных': 2,
#          'тестирование программных продуктов': 2,
#          'тестирование разработок': 2,
#          'технические системы и средства безопасности': 2,
#          'управление временем': 2,
#          'управление рисками': 2,
#          'управленческие системы': 2,
#          'фармакометрика': 2,
#          'финансовое моделирование': 2,
#          'финансовый контроль': 2,
#          'численные методы': 2,
#          'электронный документооборот': 2,
#          'эмпатия': 2,
#          '199-и': 1,
#          '1c ка': 1,
#          '1c кадры и бухгалтерия': 1,
#          '1c ух': 1,
#          '1с 8.0': 1,
#          '1с 8.3': 1,
#          '1с erp битфинанс': 1,
#          '1с erp)': 1,
#          '1с ут 11': 1,
#          '1с ут11': 1,
#          '1с:': 1,
#          '1с: бит финанс': 1,
#          '1с: бухгалтерия и склад': 1,
#          '1с: зарплата и кадры': 1,
#          '1с: логистика': 1,
#          '1с: предприятие: розница': 1,
#          '1с: управление предприятием': 1,
#          '1с:erp': 1,
#          '223-фз': 1,
#          '3624-у': 1,
#          '44-фз': 1,
#          '483-п': 1,
#          '646-п': 1,
#          'a/b/n': 1,
#          'ab тестирование': 1,
#          'abc-анализ': 1,
#          'adodb': 1,
#          'ai': 1,
#          'aiohttp': 1,
#          'aml': 1,
#          'amocrm': 1,
#          'amplitude': 1,
#          'anaconda': 1,
#          'anaconda3': 1,
#          'analyst': 1,
#          'analytic bi': 1,
#          'anti-fraud': 1,
#          'apache': 1,
#          'apache nifi': 1,
#          'api документация': 1,
#          'apple search ads': 1,
#          'appmetrica': 1,
#          'appmetrika': 1,
#          'arcgis qgis git/gitlab python пространственные базы данных agile': 1,
#          'arenadatadb (greenplum)': 1,
#          'arendata': 1,
#          'artificial intelligence': 1,
#          'asciidoc': 1,
#          'asp.net': 1,
#          'astra linux': 1,
#          'async api': 1,
#          'autocad': 1,
#          'aws': 1,
#          'aws redshift': 1,
#          'b2b исследования': 1,
#          'b2b продажи': 1,
#          'b2c': 1,
#          'backend': 1,
#          'backend -php': 1,
#          'bert': 1,
#          'beta-тестирования': 1,
#          'bff': 1,
#          'bi аналитик': 1,
#          'bi инструменты': 1,
#          'bi-система': 1,
#          'bi: visiology/microsoft powerbi': 1,
#          'bim': 1,
#          'bitrirx24': 1,
#          'bitrix crm': 1,
#          'blueprint': 1,
#          'bpm': 1,
#          'bpm online': 1,
#          'bpmnsoft': 1,
#          'bpwin': 1,
#          'brd': 1,
#          'bss': 1,
#          'bulk-запросы': 1,
#          'business development': 1,
#          'business glossary': 1,
#          'bussinessobject': 1,
#          'ca': 1,
#          'calypso': 1,
#          'cassandra': 1,
#          'cdm': 1,
#          'celery': 1,
#          'charles proxy': 1,
#          'ci\\\\cd': 1,
#          'clickup': 1,
#          'compass+': 1,
#          'confluence (желательно)': 1,
#          'crm bitrix24': 1,
#          'crm dynamics': 1,
#          'crypto': 1,
#          'css3': 1,
#          'csv': 1,
#          'cистемная аналитика': 1,
#          'daily standup': 1,
#          'dao': 1,
#          'dashboard': 1,
#          'dask': 1,
#          'data': 1,
#          'data catalog': 1,
#          'data flow': 1,
#          'data governance': 1,
#          'data lake': 1,
#          'data lens': 1,
#          'data warehouse': 1,
#          'datamine': 1,
#          'ddl': 1,
#          'ddos': 1,
#          'dds': 1,
#          'debezium': 1,
#          'demo': 1,
#          'devexpress xpo': 1,
#          'devtools': 1,
#          'dfd': 1,
#          'dft': 1,
#          'dhcp': 1,
#          'dlp': 1,
#          'dmbok dama': 1,
#          'dns': 1,
#          'docker compose': 1,
#          'doker': 1,
#          'drtm': 1,
#          'dynamics 365': 1,
#          'e-staff': 1,
#          'egar e4': 1,
#          'elastic': 1,
#          'elk': 1,
#          'elma 3': 1,
#          'elt': 1,
#          'epс': 1,
#          'er': 1,
#          'er-диаграммы': 1,
#          'erwin': 1,
#          'er‑диаграммы': 1,
#          'etl framework': 1,
#          'etl: informatica': 1,
#          'evam': 1,
#          'eviews': 1,
#          'facebook': 1,
#          'fat': 1,
#          'figmа': 1,
#          'fintech': 1,
#          'firebase': 1,
#          'fix': 1,
#          'fixml': 1,
#          'flask': 1,
#          'foodtech': 1,
#          'ga4': 1,
#          'go': 1,
#          'google adwords': 1,
#          'google big query': 1,
#          'google cloud platform': 1,
#          'gpt': 1,
#          'graphana': 1,
#          'graphviz': 1,
#          'greenplam': 1,
#          'greenplumdb': 1,
#          'gtm': 1,
#          'hcm': 1,
#          'hr-tech': 1,
#          'hr-аналитика': 1,
#          'hrm': 1,
#          'html5': 1,
#          'https': 1,
#          'hyper-v': 1,
#          'hypersonic sql': 1,
#          'ibm cognos': 1,
#          'ibm ilog cplex': 1,
#          'ibm unica': 1,
#          'icaap': 1,
#          'ide': 1,
#          'idm': 1,
#          'iiko': 1,
#          'improvado': 1,
#          'insomnia': 1,
#          'internet marketing': 1,
#          'ip телефония': 1,
#          'irb': 1,
#          'iso': 1,
#          'jenkins': 1,
#          'jetstat': 1,
#          'jira (желательно)': 1,
#          'join': 1,
#          'join)': 1,
#          'jquery': 1,
#          'json 6': 1,
#          'json)': 1,
#          'jsonata': 1,
#          'jtbd': 1,
#          'junior': 1,
#          'jupyter hab': 1,
#          'kafka)': 1,
#          'keras': 1,
#          'kerberos': 1,
#          'kotlin': 1,
#          'kvm': 1,
#          'laravel': 1,
#          'leadership skills': 1,
#          'linux kvm': 1,
#          'looker studio': 1,
#          'lowcode': 1,
#          'lr': 1,
#          'lucidchart': 1,
#          'luxms': 1,
#          'macos': 1,
#          'maplnfo professional': 1,
#          'markdown': 1,
#          'mathematical statistics': 1,
#          'matolib': 1,
#          'matomo': 1,
#          'memcashed': 1,
#          'metrics': 1,
#          'micromine': 1,
#          'microservices': 1,
#          'microsoft access': 1,
#          'microsoft office': 1,
#          'microsoft power bi': 1,
#          'mineframe': 1,
#          'miner': 1,
#          'miro/draw.io': 1,
#          'mixpanel': 1,
#          'ml модели': 1,
#          'ml-моделирование': 1,
#          'ml-прогнозирование': 1,
#          'mobile': 1,
#          'mqtt': 1,
#          'ms dynamics ax': 1,
#          'ms excel (vba': 1,
#          'ms exchange server': 1,
#          'ms olap': 1,
#          'ms visual basic': 1,
#          'ms visual studio': 1,
#          'msa': 1,
#          'msf': 1,
#          'murex': 1,
#          'nltk': 1,
#          'node-red': 1,
#          'nosql субд': 1,
#          'notion': 1,
#          'nsm': 1,
#          'nuxt': 1,
#          'ods': 1,
#          'olap инструменты': 1,
#          'olap-кубы': 1,
#          'omnigraffle': 1,
#          'oozie': 1,
#          'opc': 1,
#          'open source': 1,
#          'openai': 1,
#          'openproject': 1,
#          'openvpn': 1,
#          'openway way4': 1,
#          'oracle application express (apex)': 1,
#          'oracle primavera': 1,
#          'panda': 1,
#          'php5': 1,
#          'pim': 1,
#          'planning': 1,
#          'pmbok': 1,
#          'postgresq': 1,
#          'postman / swagger': 1,
#          'power query)': 1,
#          'powerbl': 1,
#          'powerquery': 1,
#          'prometheus': 1,
#          'python3': 1,
#          'qlickview': 1,
#          'quick sense': 1,
#          'rabbit mq': 1,
#          'raroc': 1,
#          'rational unified process': 1,
#          'react.js': 1,
#          'ready to eat': 1,
#          'realtime marketing': 1,
#          'rebbit': 1,
#          'recsys': 1,
#          'requests': 1,
#          'rest ip': 1,
#          'rest-api': 1,
#          'rest/web сервисы': 1,
#          'restapi': 1,
#          'restful api': 1,
#          'retrospective': 1,
#          'rhel': 1,
#          'rice': 1,
#          'risk weighted assets': 1,
#          'river logic': 1,
#          'roas': 1,
#          'roe': 1,
#          'roi': 1,
#          'rorac': 1,
#          'rorwa': 1,
#          'rtdm': 1,
#          'rte': 1,
#          'rtm': 1,
#          'runtime crm': 1,
#          's2t': 1,
#          'salesforce': 1,
#          'samba': 1,
#          'sap apo': 1,
#          'sap crm': 1,
#          'sap ibp': 1,
#          'sap mm': 1,
#          ...})

# %%
# разделим наиболее популярные навыки (которые встречались не менее 10 раз) на hard и soft
soft_skills = {'аналитическое мышление': 658,
               'коммуникация': 461,
               'работа с большим объемом информации': 233,
               'переговоры': 54,
               'прогнозирование': 54,
               'работа в команде': 53,
               'деловая коммуникация': 48,
               'аналитический склад ума': 46,
               'системное мышление': 45,
               'аналитические способности': 26,
               'креативность': 26,
               'системный подход': 24,
               'организаторские навыки': 22,
               'обучение и развитие': 21,
               'ответственность': 20,
               'грамотная речь': 18,
               'деловая переписка': 15,
               'навыки презентации': 13,
               'критическое мышление': 10,
               'навыки составления отчетности': 10,
               'наставничество': 10,
               'точность и внимательность к деталям': 10,
               'умение принимать решения': 10,
               'управление командой': 10
              }
hard_skills = {'документация': 1571,
               'sql': 1438, 
               'confluence': 699,
               'bpmn': 656,
               'python': 629,
               'системный анализ': 576,
               'uml': 574,
               'анализ данных': 487, 
               'rest': 394, 
               'pandas': 330,
               'работа с базами данных': 267, 
               'soap': 266,
               'аналитика': 264,
               'разработка технических заданий': 253,
               'power bi': 231,
               'бизнес-анализ': 227,
               'ms excel': 226,
               'постановка задач разработчикам': 216,
               'базы данных': 215,
               'ms sql': 212,
               'xml': 212,
               'api': 192,
               'postgresql': 181,
               'atlassian jira': 159,
               'json': 152,
               'atlassian confluence': 138,
               'data analysis': 131,
               'сбор и анализ информации': 128,
               'аналитические исследования': 123,
               'json api': 119,
               'математическая статистика': 111,'kafka': 97,
               'tableau': 95,
               'моделирование бизнес процессов': 91,
               'rest api': 87,
               'scrum': 86,
               'dwh': 84,
               'etl': 78,
               'английский язык': 77,
               'анализ бизнес показателей': 75,
               'оптимизация бизнес-процессов': 74,
               'статистический анализ': 72,
               'системная интеграция': 69,
               'ms powerpoint': 67,
               'agile': 65,
               'техническая документация': 65,
               'big data': 63,
               'a/b тесты': 60,
               'git': 56,
               'xsd': 56,
               'субд': 56,
               'юнит-экономика': 52,
               'hadoop': 50,
               'сводные таблицы': 50,
               'oracle': 49,
               'postman': 49,
               'clickhouse': 47,
               'rabbitmq': 46,
               'agile project management': 44,
               'ms visio': 43,
               'математический анализ': 42,
               'анализ требований': 41,
               'erp-системы на базе 1с': 40,
               'подготовка презентаций': 40,
               'airflow': 39,
               'ms power bi': 37,
               'swagger': 36,
               'system analysis': 33,
               'vba': 33,
               'информационные технологии': 33,
               'apache kafka': 32,
               'bi': 32,
               'spark': 32,
               'анализ рынка': 32,
               'управление проектами': 32,
               'автоматизация процессов': 31,
               'проектная документация': 31,
               'тестирование': 31,
               'numpy': 30,
               'java': 29,
               '1с': 28,
               'greenplum': 28,
               'http': 28,
               'jira': 28,
               'power query': 28,
               'powerbi': 28,
               'user story': 28,
               'business analysis': 27,
               'визуализация данных': 27,
               'разработка по': 27,
               'excel': 26,
               '1с: предприятие 8': 25,
               'сбор требований': 25,
               '1с: управление торговлей': 24,
               'подготовка отчетов': 24,
               '1с: предприятие': 22,
               'linux': 22,
               'use case analysis': 22,
               'описание бизнес-процессов': 22,
               'machine learning': 20,
               'dax': 19,
               '1с: зарплата и управление персоналом': 18,
               'data science': 18,
               'javascript': 18,
               'mysql': 18,
               'маркетинговый анализ': 18,
               'idef': 17,
               'ml': 17,
               'разработка инструкций': 17,
               'разработка проектной документации': 17,
               '1с программирование': 16,
               'google analytics': 16,
               'oracle pl/sql': 16,
               'superset': 16,
               'экономический анализ': 16,
               '1с: документооборот': 15,
               'html': 15,
               'mq': 15,
               'nosql': 15,
               'r': 15,
               'анализ бизнес-процессов': 15,
               'математическое моделирование': 15,
               '1с: управление производственным предприятием': 14,
               'figma': 14,
               'аналитика продаж': 14,
               'микросервисная архитектура': 14,
               'crm': 13,
               'docker': 13,
               'grafana': 13,
               'power pivot': 13,
               'pytorch': 13,
               'qlik sense': 13,
               'ui': 13,
               'waterfall': 13,
               'бухгалтерский учет': 13,
               'торговая площадка': 13,
               'управленческая отчетность': 13,
               'финансовый анализ': 13,
               'datalens': 12,
               'draw.io': 12,
               'kanban': 12,
               'написание тз': 12,
               'работа с системами аналитики': 12,
               'складская логистика': 12,
               'ad hoc analysis': 11,
               'erp': 11,
               'hive': 11,
               'mongodb': 11,
               'ms office': 11,
               'openapi': 11,
               'teradata': 11,
               'use cases': 11,
               'wms': 11,
               'витрины данных': 11,
               'впр': 11,
               'документирование бизнес-требований': 11,
               'управление требованиями': 11,
               'camunda': 10,
               'erd': 10,
               'google docs': 10,
               'soa': 10,
               'ui/ux': 10,
               'web аналитика': 10,
               'wsdl': 10,
               'анализ рисков': 10,
               'аналитика данных': 10,
               'интеграции': 10,
               'оптимизация бизнес процессов': 10,
               'пользователь пк': 10,
               'проектирование баз данных': 10                 
              }

# %%
# доролнительно сформируем список наиболее популярных навыков, которые встерчались не менее 10 раз 
popular_skills = [key for key, value in skills.items() if value >= 10]
print(popular_skills)
# Out:
# ['', '1с', '1с программирование', '1с: документооборот', '1с: зарплата и управление персоналом', '1с: предприятие', '1с: предприятие 8', '1с: управление производственным предприятием', '1с: управление торговлей', 'a/b тесты', 'ad hoc analysis', 'agile', 'agile project management', 'airflow', 'apache kafka', 'api', 'atlassian confluence', 'atlassian jira', 'bi', 'big data', 'bpmn', 'business analysis', 'camunda', 'clickhouse', 'confluence', 'crm', 'data analysis', 'data science', 'datalens', 'dax', 'docker', 'draw.io', 'dwh', 'erd', 'erp', 'erp-системы на базе 1с', 'etl', 'excel', 'figma', 'git', 'google analytics', 'google docs', 'grafana', 'greenplum', 'hadoop', 'hive', 'html', 'http', 'idef', 'java', 'javascript', 'jira', 'json', 'json api', 'kafka', 'kanban', 'linux', 'machine learning', 'ml', 'mongodb', 'mq', 'ms excel', 'ms office', 'ms power bi', 'ms powerpoint', 'ms sql', 'ms visio', 'mysql', 'nosql', 'numpy', 'openapi', 'oracle', 'oracle pl/sql', 'pandas', 'postgresql', 'postman', 'power bi', 'power pivot', 'power query', 'powerbi', 'python', 'pytorch', 'qlik sense', 'r', 'rabbitmq', 'rest', 'rest api', 'scrum', 'soa', 'soap', 'spark', 'sql', 'superset', 'swagger', 'system analysis', 'tableau', 'teradata', 'ui', 'ui/ux', 'uml', 'use case analysis', 'use cases', 'user story', 'vba', 'waterfall', 'web аналитика', 'wms', 'wsdl', 'xml', 'xsd', 'автоматизация процессов', 'анализ бизнес показателей', 'анализ бизнес-процессов', 'анализ данных', 'анализ рисков', 'анализ рынка', 'анализ требований', 'аналитика', 'аналитика данных', 'аналитика продаж', 'аналитические исследования', 'аналитические способности', 'аналитический склад ума', 'аналитическое мышление', 'английский язык', 'базы данных', 'бизнес-анализ', 'бухгалтерский учет', 'визуализация данных', 'витрины данных', 'впр', 'грамотная речь', 'деловая коммуникация', 'деловая переписка', 'документация', 'документирование бизнес-требований', 'интеграции', 'информационные технологии', 'коммуникация', 'креативность', 'критическое мышление', 'маркетинговый анализ', 'математическая статистика', 'математический анализ', 'математическое моделирование', 'микросервисная архитектура', 'моделирование бизнес процессов', 'навыки презентации', 'навыки составления отчетности', 'написание тз', 'наставничество', 'обучение и развитие', 'описание бизнес-процессов', 'оптимизация бизнес процессов', 'оптимизация бизнес-процессов', 'организаторские навыки', 'ответственность', 'переговоры', 'подготовка отчетов', 'подготовка презентаций', 'пользователь пк', 'постановка задач разработчикам', 'проактивность', 'прогнозирование', 'проектирование баз данных', 'проектная документация', 'работа в команде', 'работа с базами данных', 'работа с большим объемом информации', 'работа с системами аналитики', 'разработка инструкций', 'разработка по', 'разработка проектной документации', 'разработка технических заданий', 'сбор и анализ информации', 'сбор требований', 'сводные таблицы', 'системная интеграция', 'системное мышление', 'системный анализ', 'системный подход', 'складская логистика', 'статистика', 'статистический анализ', 'субд', 'тестирование', 'техническая документация', 'торговая площадка', 'точность и внимательность к деталям', 'удаленная работа', 'умение принимать решения', 'управление командой', 'управление проектами', 'управление требованиями', 'управленческая отчетность', 'финансовый анализ', 'экономический анализ', 'юнит-экономика']

# %%
# функция, чтобы создать поля с hard и soft навыками исходя из заранее подготовленных списков навыков и навыков в key_skills
def get_skills(x, skills):
    hard = []
    for skill in x:
        if skill.strip() in skills:
            hard += [skill.strip()]
    return hard

hh_data['hard_skills'] = hh_data['key_skills'].apply(lambda x: get_skills(x, hard_skills))
hh_data['soft_skills'] = hh_data['key_skills'].apply(lambda x: get_skills(x, soft_skills))
hh_data[['key_skills','hard_skills_from_description','soft_skills_from_description','hard_skills','soft_skills']]
# Out:
#                                              key_skills  \
# 0                      [power bi,  субд,  python,  sql]
# 1          [ms sql,  работа с базами данных,  ms excel]
# 2     [sql,  power bi,  субд,  python,  clickhouse, ...
# 3     [анализ данных,  коммуникация,  sql,  ms offic...
# 4                                        [документация]
# ...                                                 ...
# 3711                      [документация,  коммуникация]
# 3712  [idef,  разработка технических заданий,  rest,...
# 3713                                                 []
# 3714  [soa,  xml,  atlassian jira,  use cases,  db2,...
# 3715  [документация,  1с: предприятие,  1с: бит фина...
#
#      hard_skills_from_description soft_skills_from_description  \
# 0                             NaN                          NaN
# 1                             NaN                          NaN
# 2                             NaN                          NaN
# 3          Pandas, Юнит-экономика                 Коммуникация
# 4                             NaN                 Документация
# ...                           ...                          ...
# 3711                          NaN   Коммуникация, Документация
# 3712                          NaN                 Документация
# 3713                          NaN                          NaN
# 3714                   confluence                          NaN
# 3715                          NaN                 Документация
#
#                                             hard_skills  \
# 0                         [power bi, субд, python, sql]
# 1            [ms sql, работа с базами данных, ms excel]
# 2       [sql, power bi, субд, python, clickhouse, bpmn]
# 3     [анализ данных, sql, ms office, python, аналит...
# 4                                        [документация]
# ...                                                 ...
# 3711                                     [документация]
# 3712  [idef, разработка технических заданий, rest, б...
# 3713                                                 []
# 3714  [soa, xml, atlassian jira, use cases, bpmn, ap...
# 3715          [документация, 1с: предприятие, ms excel]
#
#                                             soft_skills
# 0                                                    []
# 1                                                    []
# 2                                                    []
# 3     [коммуникация, управление командой, работа с б...
# 4                                                    []
# ...                                                 ...
# 3711                                     [коммуникация]
# 3712                                                 []
# 3713                                                 []
# 3714                                                 []
# 3715                                                 []
#
# [3716 rows x 5 columns]

# %%
# cформируем таблицы с навыками в зависимости от грейда и типа вакансий
hard_skills = hh_data[['profession_type', 'experience','hard_skills']].explode('hard_skills').\
        groupby(['profession_type','experience','hard_skills']).size().rename('hard_skill_cnt').reset_index()

soft_skills = hh_data[['profession_type', 'experience','soft_skills']].explode('soft_skills').\
        groupby(['profession_type','experience','soft_skills']).size().rename('soft_skill_cnt').reset_index()

# %%
# посмотрим ТОП-5 soft и hard навыков для каждого грейда
result_hard = hard_skills.groupby(['profession_type','experience']).apply(lambda x: x.nlargest(5, 'hard_skill_cnt')).reset_index(drop=True)
result_soft = soft_skills.groupby(['profession_type','experience']).apply(lambda x: x.nlargest(5, 'soft_skill_cnt')).reset_index(drop=True)


display(result_hard)
display(result_soft)
# Out:
#    profession_type             experience       hard_skills  hard_skill_cnt
# 0     data_analyst  Junior (no experince)               sql              37
# 1     data_analyst  Junior (no experince)            python              34
# 2     data_analyst  Junior (no experince)     анализ данных              31
# 3     data_analyst  Junior (no experince)          ms excel              28
# 4     data_analyst  Junior (no experince)            pandas              21
# 5     data_analyst    Junior+ (1-3 years)               sql             469
# 6     data_analyst    Junior+ (1-3 years)            python             321
# 7     data_analyst    Junior+ (1-3 years)     анализ данных             262
# 8     data_analyst    Junior+ (1-3 years)            pandas             186
# 9     data_analyst    Junior+ (1-3 years)      документация             150
# 10    data_analyst     Middle (3-6 years)               sql             250
# 11    data_analyst     Middle (3-6 years)            python             217
# 12    data_analyst     Middle (3-6 years)            pandas             116
# 13    data_analyst     Middle (3-6 years)     анализ данных             114
# 14    data_analyst     Middle (3-6 years)      документация             109
# 15    data_analyst      Senior (6+ years)            python               9
# 16    data_analyst      Senior (6+ years)               sql               9
# 17    data_analyst      Senior (6+ years)        confluence               4
# 18    data_analyst      Senior (6+ years)            pandas               4
# 19    data_analyst      Senior (6+ years)          power bi               4
# 20  system_analyst  Junior (no experince)      документация              50
# 21  system_analyst  Junior (no experince)               sql              34
# 22  system_analyst  Junior (no experince)  системный анализ              27
# 23  system_analyst  Junior (no experince)     бизнес-анализ              22
# 24  system_analyst  Junior (no experince)              bpmn              21
# 25  system_analyst    Junior+ (1-3 years)      документация             554
# 26  system_analyst    Junior+ (1-3 years)              bpmn             280
# 27  system_analyst    Junior+ (1-3 years)               sql             276
# 28  system_analyst    Junior+ (1-3 years)        confluence             245
# 29  system_analyst    Junior+ (1-3 years)               uml             237
# 30  system_analyst     Middle (3-6 years)      документация             658
# 31  system_analyst     Middle (3-6 years)               sql             343
# 32  system_analyst     Middle (3-6 years)              bpmn             317
# 33  system_analyst     Middle (3-6 years)        confluence             314
# 34  system_analyst     Middle (3-6 years)  системный анализ             298
# 35  system_analyst      Senior (6+ years)      документация              29
# 36  system_analyst      Senior (6+ years)               sql              20
# 37  system_analyst      Senior (6+ years)              bpmn              17
# 38  system_analyst      Senior (6+ years)               uml              17
# 39  system_analyst      Senior (6+ years)  системный анализ              16
#    profession_type             experience  \
# 0     data_analyst  Junior (no experince)
# 1     data_analyst  Junior (no experince)
# 2     data_analyst  Junior (no experince)
# 3     data_analyst  Junior (no experince)
# 4     data_analyst  Junior (no experince)
# 5     data_analyst    Junior+ (1-3 years)
# 6     data_analyst    Junior+ (1-3 years)
# 7     data_analyst    Junior+ (1-3 years)
# 8     data_analyst    Junior+ (1-3 years)
# 9     data_analyst    Junior+ (1-3 years)
# 10    data_analyst     Middle (3-6 years)
# 11    data_analyst     Middle (3-6 years)
# 12    data_analyst     Middle (3-6 years)
# 13    data_analyst     Middle (3-6 years)
# 14    data_analyst     Middle (3-6 years)
# 15    data_analyst      Senior (6+ years)
# 16    data_analyst      Senior (6+ years)
# 17    data_analyst      Senior (6+ years)
# 18  system_analyst  Junior (no experince)
# 19  system_analyst  Junior (no experince)
# 20  system_analyst  Junior (no experince)
# 21  system_analyst  Junior (no experince)
# 22  system_analyst  Junior (no experince)
# 23  system_analyst    Junior+ (1-3 years)
# 24  system_analyst    Junior+ (1-3 years)
# 25  system_analyst    Junior+ (1-3 years)
# 26  system_analyst    Junior+ (1-3 years)
# 27  system_analyst    Junior+ (1-3 years)
# 28  system_analyst     Middle (3-6 years)
# 29  system_analyst     Middle (3-6 years)
# 30  system_analyst     Middle (3-6 years)
# 31  system_analyst     Middle (3-6 years)
# 32  system_analyst     Middle (3-6 years)
# 33  system_analyst      Senior (6+ years)
# 34  system_analyst      Senior (6+ years)
# 35  system_analyst      Senior (6+ years)
# 36  system_analyst      Senior (6+ years)
# 37  system_analyst      Senior (6+ years)
#
#                             soft_skills  soft_skill_cnt
# 0                аналитическое мышление              40
# 1   работа с большим объемом информации              19
# 2                          коммуникация              17
# 3                      работа в команде               6
# 4                          креативность               4
# 5                аналитическое мышление             241
# 6   работа с большим объемом информации             119
# 7                          коммуникация             105
# 8                       прогнозирование              26
# 9                  деловая коммуникация              19
# 10               аналитическое мышление              82
# 11                         коммуникация              56
# 12  работа с большим объемом информации              45
# 13                      прогнозирование              24
# 14            аналитические способности              10
# 15                         коммуникация               3
# 16               аналитическое мышление               2
# 17                      прогнозирование               2
# 18               аналитическое мышление              46
# 19              аналитический склад ума              18
# 20                  обучение и развитие               9
# 21                         коммуникация               8
# 22               организаторские навыки               8
# 23               аналитическое мышление             158
# 24                         коммуникация             127
# 25  работа с большим объемом информации              24
# 26                   системное мышление              18
# 27                           переговоры              17
# 28                         коммуникация             138
# 29               аналитическое мышление              87
# 30                           переговоры              20
# 31  работа с большим объемом информации              19
# 32                   системное мышление              14
# 33                         коммуникация               7
# 34               аналитическое мышление               2
# 35                         креативность               2
# 36                           переговоры               2
# 37                 деловая коммуникация               1

# %% [markdown]
# <div style="border:solid green 1px; padding: 10px">
# Вывод:
# hard-навыки почти одинаковы для всех грейдов
#
# наиболее востребованные hard-навыки для дата аналитиков:
#     sql, python, pandas, анализ данных, документация
#
# наиболее востребованные hard-навыки для системных аналитиков:
#     документация, bpmn, sql, confluence, системный анализ
#
# soft-навыки идентичны для обоих типов специальностей (дата и системный аналитик) и также  почти одинаковы для всех грейдов.
# Наиболее востребованные soft-навыки: аналитическое мышление, работа с большим объемом информации, коммуникация

# %%
# найдем средний процент hard навыков от всех навыков
hh_data['hard_skills_cnt'] = hh_data['hard_skills'].apply(len)
hh_data['soft_skills_cnt'] = hh_data['soft_skills'].apply(len)
hh_data['all_skills_cnt'] = hh_data['hard_skills_cnt'] + hh_data['soft_skills_cnt']
round((hh_data['hard_skills_cnt'] / hh_data['all_skills_cnt']).mean() * 100, 2)
# Out:
# 86.31

# %% [markdown]
# <div style="border:solid green 1px; padding: 10px">
# Вывод: большую часть требований (более 85%) составляют hard навыки, т.о. специальности дата и системного аналитика требуют больше технических компетенций, чем soft навыков, особенно на начальных и средних позициях.

# %% [markdown]
# <a id="cell3.2"></a>
# ### Анализ вакансий в разбивке по грейдам и регионам

# %%
# подсчет количества и доли вакансий в разбивке по опыту работы
hh_count = hh_data['id'].count() # подсчет общего количества всех вакансий

experience = hh_data.groupby('experience').agg(
        count_vacancies=('id', 'count'),  
        percentage=('id', lambda x: x.count() / hh_count * 100)  
    ).reset_index()

# визуализируем доли на диаграмме 
ax = experience.plot(
    kind='bar',x='experience', y='percentage', 
    ylabel = 'percent of total', 
    title ='Доля вакансий в разбивке по опыту работы',
    legend = False, 
    grid=True)
plt.xticks(rotation=45)

# Добавляем метки значений
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x = p.get_x() + width / 2
    y = p.get_y() + height
    
    # Отображаем процентное значение с округлением до 1 знака после запятой
    ax.annotate(f'{height:.1f}%', 
                (x, y), 
                ha='center', 
                va='bottom', 
                fontsize=10)
plt.show()

# %%
# подсчет количества вакансий в разбивке по опыту работы и городу
(hh_data.pivot_table(
    index='area',
    columns=['profession_type','experience'],
    values='name',
    aggfunc='count',
    margins=True
).sort_values('All', ascending=False)).round(0).head(16).fillna(0).astype(int)\
.style.background_gradient(axis=None)
# Out:
# <style  type="text/css" >
# #T_33fa2_row0_col0{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_33fa2_row0_col1{
#             background-color:  #c1cae2;
#             color:  #000000;
#         }#T_33fa2_row0_col2{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_33fa2_row0_col3,#T_33fa2_row1_col3,#T_33fa2_row2_col3,#T_33fa2_row2_col4,#T_33fa2_row2_col7,#T_33fa2_row3_col0,#T_33fa2_row3_col2,#T_33fa2_row3_col3,#T_33fa2_row3_col4,#T_33fa2_row3_col7,#T_33fa2_row4_col0,#T_33fa2_row4_col2,#T_33fa2_row4_col3,#T_33fa2_row4_col4,#T_33fa2_row4_col7,#T_33fa2_row5_col0,#T_33fa2_row5_col2,#T_33fa2_row5_col3,#T_33fa2_row5_col4,#T_33fa2_row5_col7,#T_33fa2_row6_col0,#T_33fa2_row6_col2,#T_33fa2_row6_col3,#T_33fa2_row6_col4,#T_33fa2_row6_col6,#T_33fa2_row6_col7,#T_33fa2_row7_col0,#T_33fa2_row7_col2,#T_33fa2_row7_col3,#T_33fa2_row7_col4,#T_33fa2_row7_col6,#T_33fa2_row7_col7,#T_33fa2_row8_col0,#T_33fa2_row8_col2,#T_33fa2_row8_col3,#T_33fa2_row8_col4,#T_33fa2_row8_col5,#T_33fa2_row8_col6,#T_33fa2_row8_col7,#T_33fa2_row9_col0,#T_33fa2_row9_col1,#T_33fa2_row9_col2,#T_33fa2_row9_col3,#T_33fa2_row9_col4,#T_33fa2_row9_col6,#T_33fa2_row9_col7,#T_33fa2_row10_col0,#T_33fa2_row10_col1,#T_33fa2_row10_col2,#T_33fa2_row10_col3,#T_33fa2_row10_col4,#T_33fa2_row10_col5,#T_33fa2_row10_col6,#T_33fa2_row10_col7,#T_33fa2_row11_col0,#T_33fa2_row11_col1,#T_33fa2_row11_col2,#T_33fa2_row11_col3,#T_33fa2_row11_col4,#T_33fa2_row11_col5,#T_33fa2_row11_col6,#T_33fa2_row11_col7,#T_33fa2_row12_col0,#T_33fa2_row12_col1,#T_33fa2_row12_col2,#T_33fa2_row12_col3,#T_33fa2_row12_col4,#T_33fa2_row12_col5,#T_33fa2_row12_col6,#T_33fa2_row12_col7,#T_33fa2_row13_col0,#T_33fa2_row13_col1,#T_33fa2_row13_col2,#T_33fa2_row13_col3,#T_33fa2_row13_col4,#T_33fa2_row13_col5,#T_33fa2_row13_col6,#T_33fa2_row13_col7,#T_33fa2_row14_col0,#T_33fa2_row14_col1,#T_33fa2_row14_col2,#T_33fa2_row14_col3,#T_33fa2_row14_col4,#T_33fa2_row14_col5,#T_33fa2_row14_col6,#T_33fa2_row14_col7,#T_33fa2_row15_col0,#T_33fa2_row15_col1,#T_33fa2_row15_col2,#T_33fa2_row15_col3,#T_33fa2_row15_col4,#T_33fa2_row15_col5,#T_33fa2_row15_col6,#T_33fa2_row15_col7{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_33fa2_row0_col4,#T_33fa2_row4_col8,#T_33fa2_row5_col8{
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }#T_33fa2_row0_col5{
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }#T_33fa2_row0_col6{
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }#T_33fa2_row0_col7,#T_33fa2_row1_col0,#T_33fa2_row2_col2,#T_33fa2_row6_col8,#T_33fa2_row7_col8{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_33fa2_row0_col8{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_33fa2_row1_col1{
#             background-color:  #dcdaeb;
#             color:  #000000;
#         }#T_33fa2_row1_col2,#T_33fa2_row1_col5{
#             background-color:  #eee8f3;
#             color:  #000000;
#         }#T_33fa2_row1_col4,#T_33fa2_row2_col0,#T_33fa2_row3_col6,#T_33fa2_row4_col1,#T_33fa2_row4_col6,#T_33fa2_row5_col1,#T_33fa2_row5_col5,#T_33fa2_row5_col6,#T_33fa2_row6_col1,#T_33fa2_row6_col5,#T_33fa2_row7_col1,#T_33fa2_row7_col5,#T_33fa2_row8_col1,#T_33fa2_row9_col5,#T_33fa2_row12_col8,#T_33fa2_row13_col8,#T_33fa2_row14_col8,#T_33fa2_row15_col8{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_33fa2_row1_col6{
#             background-color:  #e1dfed;
#             color:  #000000;
#         }#T_33fa2_row1_col7,#T_33fa2_row3_col1,#T_33fa2_row3_col5,#T_33fa2_row4_col5,#T_33fa2_row8_col8,#T_33fa2_row9_col8,#T_33fa2_row10_col8,#T_33fa2_row11_col8{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_33fa2_row1_col8{
#             background-color:  #2f8bbe;
#             color:  #000000;
#         }#T_33fa2_row2_col1,#T_33fa2_row2_col6,#T_33fa2_row3_col8{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_33fa2_row2_col5{
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }#T_33fa2_row2_col8{
#             background-color:  #efe9f3;
#             color:  #000000;
#         }</style><table id="T_33fa2_" ><thead>    <tr>        <th class="index_name level0" >profession_type</th>        <th class="col_heading level0 col0" colspan="4">data_analyst</th>        <th class="col_heading level0 col4" colspan="4">system_analyst</th>        <th class="col_heading level0 col8" >All</th>    </tr>    <tr>        <th class="index_name level1" >experience</th>        <th class="col_heading level1 col0" >Junior (no experince)</th>        <th class="col_heading level1 col1" >Junior+ (1-3 years)</th>        <th class="col_heading level1 col2" >Middle (3-6 years)</th>        <th class="col_heading level1 col3" >Senior (6+ years)</th>        <th class="col_heading level1 col4" >Junior (no experince)</th>        <th class="col_heading level1 col5" >Junior+ (1-3 years)</th>        <th class="col_heading level1 col6" >Middle (3-6 years)</th>        <th class="col_heading level1 col7" >Senior (6+ years)</th>        <th class="col_heading level1 col8" ></th>    </tr>    <tr>        <th class="index_name level0" >area</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_33fa2_level0_row0" class="row_heading level0 row0" >All</th>
#                         <td id="T_33fa2_row0_col0" class="data row0 col0" >142</td>
#                         <td id="T_33fa2_row0_col1" class="data row0 col1" >1091</td>
#                         <td id="T_33fa2_row0_col2" class="data row0 col2" >555</td>
#                         <td id="T_33fa2_row0_col3" class="data row0 col3" >13</td>
#                         <td id="T_33fa2_row0_col4" class="data row0 col4" >86</td>
#                         <td id="T_33fa2_row0_col5" class="data row0 col5" >852</td>
#                         <td id="T_33fa2_row0_col6" class="data row0 col6" >933</td>
#                         <td id="T_33fa2_row0_col7" class="data row0 col7" >44</td>
#                         <td id="T_33fa2_row0_col8" class="data row0 col8" >3716</td>
#             </tr>
#             <tr>
#                         <th id="T_33fa2_level0_row1" class="row_heading level0 row1" >Москва</th>
#                         <td id="T_33fa2_row1_col0" class="data row1 col0" >71</td>
#                         <td id="T_33fa2_row1_col1" class="data row1 col1" >732</td>
#                         <td id="T_33fa2_row1_col2" class="data row1 col2" >431</td>
#                         <td id="T_33fa2_row1_col3" class="data row1 col3" >13</td>
#                         <td id="T_33fa2_row1_col4" class="data row1 col4" >27</td>
#                         <td id="T_33fa2_row1_col5" class="data row1 col5" >434</td>
#                         <td id="T_33fa2_row1_col6" class="data row1 col6" >640</td>
#                         <td id="T_33fa2_row1_col7" class="data row1 col7" >33</td>
#                         <td id="T_33fa2_row1_col8" class="data row1 col8" >2381</td>
#             </tr>
#             <tr>
#                         <th id="T_33fa2_level0_row2" class="row_heading level0 row2" >Санкт-Петербург</th>
#                         <td id="T_33fa2_row2_col0" class="data row2 col0" >19</td>
#                         <td id="T_33fa2_row2_col1" class="data row2 col1" >106</td>
#                         <td id="T_33fa2_row2_col2" class="data row2 col2" >56</td>
#                         <td id="T_33fa2_row2_col3" class="data row2 col3" >0</td>
#                         <td id="T_33fa2_row2_col4" class="data row2 col4" >6</td>
#                         <td id="T_33fa2_row2_col5" class="data row2 col5" >100</td>

# %% [markdown]
# <div style="border:solid green 1px; padding: 10px">
# Вывод:
#
# - наиболее востребованы специалисты c опытом работы: уровня Junior+ и Middle. При этом  у дата-аналитиков более востребованы специалисты Junior+, а в вакансиях системного аналитика более востребованы специалисты Middle.  Начинающим дата-аналитикам будет проще найти вакансию.
# - Москва с существенным отрывом лидирует по числу размещенных вакансий обоих типов (почти 65% всех размещенных вакансий), на втором месте - СПб (примерно 10% всех вакансий), в ТОП-5 также входят другие города-миллионники (Екатеринбург, Новосибирск, Казань, Н.Новгород), на эти 4 города в совокупности приходится порядка 9% вакансий.
# - Специалисты без опыта мало востребованы на рынке труда (6% всех размещенных вакансий)
# - Следует отметить очень низкое предложение вакансий обоих типов для Senior специалистов (1.5% всех размещенных вакансий). Возможно, это связано с тем, что  HH.ru  - площадка, более ориентированная на специалистов массовых сегментов, а Senior специалисты используют другие более узко специализированные площадки

# %% [markdown]
# Дополнительно проанализируем какие работодатели готовы нанимать специалистов без опыта

# %%
# фильтруем данные по опыту, затем сводим в таблицу, подсчитываем количество вакансий
hh_data.loc[hh_data['experience']=='Junior (no experince)'].pivot_table(
    index='employer',
    columns=['profession_type','experience'],
    values='name',
    aggfunc='count',
    margins=True
).sort_values('All', ascending=False).head(16).fillna(0).query('employer!= "All"').astype(int)\
.style.background_gradient(axis=None)
# Out:
# <style  type="text/css" >
# #T_04f9e_row0_col0,#T_04f9e_row2_col0,#T_04f9e_row3_col1,#T_04f9e_row5_col0,#T_04f9e_row6_col0,#T_04f9e_row7_col1,#T_04f9e_row8_col1,#T_04f9e_row9_col1,#T_04f9e_row12_col0,#T_04f9e_row13_col0,#T_04f9e_row14_col1{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_04f9e_row0_col1,#T_04f9e_row0_col2{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_04f9e_row1_col0{
#             background-color:  #04649e;
#             color:  #f1f1f1;
#         }#T_04f9e_row1_col1,#T_04f9e_row4_col0,#T_04f9e_row10_col0,#T_04f9e_row11_col0{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }#T_04f9e_row1_col2{
#             background-color:  #034871;
#             color:  #f1f1f1;
#         }#T_04f9e_row2_col1,#T_04f9e_row2_col2{
#             background-color:  #73a9cf;
#             color:  #000000;
#         }#T_04f9e_row3_col0,#T_04f9e_row3_col2{
#             background-color:  #8cb3d5;
#             color:  #000000;
#         }#T_04f9e_row4_col1,#T_04f9e_row9_col0,#T_04f9e_row9_col2,#T_04f9e_row10_col2,#T_04f9e_row11_col2,#T_04f9e_row12_col1,#T_04f9e_row12_col2,#T_04f9e_row13_col1,#T_04f9e_row13_col2,#T_04f9e_row14_col0,#T_04f9e_row14_col2{
#             background-color:  #dedcec;
#             color:  #000000;
#         }#T_04f9e_row4_col2,#T_04f9e_row5_col1,#T_04f9e_row5_col2{
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }#T_04f9e_row6_col1,#T_04f9e_row6_col2,#T_04f9e_row7_col0,#T_04f9e_row7_col2,#T_04f9e_row8_col0,#T_04f9e_row8_col2{
#             background-color:  #d0d1e6;
#             color:  #000000;
#         }#T_04f9e_row10_col1,#T_04f9e_row11_col1{
#             background-color:  #f5eff6;
#             color:  #000000;
#         }</style><table id="T_04f9e_" ><thead>    <tr>        <th class="index_name level0" >profession_type</th>        <th class="col_heading level0 col0" >data_analyst</th>        <th class="col_heading level0 col1" >system_analyst</th>        <th class="col_heading level0 col2" >All</th>    </tr>    <tr>        <th class="index_name level1" >experience</th>        <th class="col_heading level1 col0" >Junior (no experince)</th>        <th class="col_heading level1 col1" >Junior (no experince)</th>        <th class="col_heading level1 col2" ></th>    </tr>    <tr>        <th class="index_name level0" >employer</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_04f9e_level0_row0" class="row_heading level0 row0" >Aston</th>
#                         <td id="T_04f9e_row0_col0" class="data row0 col0" >0</td>
#                         <td id="T_04f9e_row0_col1" class="data row0 col1" >16</td>
#                         <td id="T_04f9e_row0_col2" class="data row0 col2" >16</td>
#             </tr>
#             <tr>
#                         <th id="T_04f9e_level0_row1" class="row_heading level0 row1" >СБЕР</th>
#                         <td id="T_04f9e_row1_col0" class="data row1 col0" >13</td>
#                         <td id="T_04f9e_row1_col1" class="data row1 col1" >2</td>
#                         <td id="T_04f9e_row1_col2" class="data row1 col2" >15</td>
#             </tr>
#             <tr>
#                         <th id="T_04f9e_level0_row2" class="row_heading level0 row2" >Компания Апогей (1С-франчайзи)</th>
#                         <td id="T_04f9e_row2_col0" class="data row2 col0" >0</td>
#                         <td id="T_04f9e_row2_col1" class="data row2 col1" >8</td>
#                         <td id="T_04f9e_row2_col2" class="data row2 col2" >8</td>
#             </tr>
#             <tr>
#                         <th id="T_04f9e_level0_row3" class="row_heading level0 row3" >МАГНИТ, Розничная сеть</th>
#                         <td id="T_04f9e_row3_col0" class="data row3 col0" >7</td>
#                         <td id="T_04f9e_row3_col1" class="data row3 col1" >0</td>
#                         <td id="T_04f9e_row3_col2" class="data row3 col2" >7</td>
#             </tr>
#             <tr>
#                         <th id="T_04f9e_level0_row4" class="row_heading level0 row4" >Центр финансовых технологий</th>
#                         <td id="T_04f9e_row4_col0" class="data row4 col0" >2</td>
#                         <td id="T_04f9e_row4_col1" class="data row4 col1" >3</td>
#                         <td id="T_04f9e_row4_col2" class="data row4 col2" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_04f9e_level0_row5" class="row_heading level0 row5" >TWIGA Communication Group</th>
#                         <td id="T_04f9e_row5_col0" class="data row5 col0" >0</td>
#                         <td id="T_04f9e_row5_col1" class="data row5 col1" >5</td>
#                         <td id="T_04f9e_row5_col2" class="data row5 col2" >5</td>
#             </tr>
#             <tr>
#                         <th id="T_04f9e_level0_row6" class="row_heading level0 row6" >Дунайс</th>
#                         <td id="T_04f9e_row6_col0" class="data row6 col0" >0</td>
#                         <td id="T_04f9e_row6_col1" class="data row6 col1" >4</td>
#                         <td id="T_04f9e_row6_col2" class="data row6 col2" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_04f9e_level0_row7" class="row_heading level0 row7" >Согласие, страховая компания</th>
#                         <td id="T_04f9e_row7_col0" class="data row7 col0" >4</td>
#                         <td id="T_04f9e_row7_col1" class="data row7 col1" >0</td>
#                         <td id="T_04f9e_row7_col2" class="data row7 col2" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_04f9e_level0_row8" class="row_heading level0 row8" >DNS Технологии</th>
#                         <td id="T_04f9e_row8_col0" class="data row8 col0" >4</td>
#                         <td id="T_04f9e_row8_col1" class="data row8 col1" >0</td>
#                         <td id="T_04f9e_row8_col2" class="data row8 col2" >4</td>
#             </tr>
#             <tr>
#                         <th id="T_04f9e_level0_row9" class="row_heading level0 row9" >ANCOR</th>
#                         <td id="T_04f9e_row9_col0" class="data row9 col0" >3</td>
#                         <td id="T_04f9e_row9_col1" class="data row9 col1" >0</td>
#                         <td id="T_04f9e_row9_col2" class="data row9 col2" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_04f9e_level0_row10" class="row_heading level0 row10" >Автомакон</th>
#                         <td id="T_04f9e_row10_col0" class="data row10 col0" >2</td>
#                         <td id="T_04f9e_row10_col1" class="data row10 col1" >1</td>
#                         <td id="T_04f9e_row10_col2" class="data row10 col2" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_04f9e_level0_row11" class="row_heading level0 row11" >Ozon</th>
#                         <td id="T_04f9e_row11_col0" class="data row11 col0" >2</td>
#                         <td id="T_04f9e_row11_col1" class="data row11 col1" >1</td>
#                         <td id="T_04f9e_row11_col2" class="data row11 col2" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_04f9e_level0_row12" class="row_heading level0 row12" >Т1</th>
#                         <td id="T_04f9e_row12_col0" class="data row12 col0" >0</td>
#                         <td id="T_04f9e_row12_col1" class="data row12 col1" >3</td>
#                         <td id="T_04f9e_row12_col2" class="data row12 col2" >3</td>
#             </tr>
#             <tr>
#                         <th id="T_04f9e_level0_row13" class="row_heading level0 row13" >Ред Софт</th>
#                         <td id="T_04f9e_row13_col0" class="data row13 col0" >0</td>
#                         <td id="T_04f9e_row13_col1" class="data row13 col1" >3</td>
#                         <td id="T_04f9e_row13_col2" class="data row13 col2" >3</td>
#             </tr>
#             <tr>
#                         <th id=

# %% [markdown]
# <div style="border:solid green 1px; padding: 10px">
# Вывод: вакансии для специалистов без опыта в основном размещают специализированные ИТ-компании и крупные технологические компании (бигтех)

# %% [markdown]
# <a id="cell3.3"></a>
# ### Анализ работодателей

# %% [markdown]
# Посмотрим ТОП крупнейших работодателей по количеству вакансий

# %%
# подсчет количества вакансий в разбивке по опыту работы и работодателю
hh_data.pivot_table(
    index='employer',
    columns=['profession_type','experience'],
    values='name',
    aggfunc='count',
    margins=True
).sort_values('All', ascending=False).head(16).fillna(0).query('employer != "All"').astype(int)\
.style.background_gradient(axis=None)
# Out:
# <style  type="text/css" >
# #T_355a8_row0_col0,#T_355a8_row11_col1,#T_355a8_row12_col5,#T_355a8_row13_col1{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_355a8_row0_col1{
#             background-color:  #80aed2;
#             color:  #000000;
#         }#T_355a8_row0_col2{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_355a8_row0_col3,#T_355a8_row0_col7,#T_355a8_row1_col0,#T_355a8_row1_col3,#T_355a8_row2_col0,#T_355a8_row2_col1,#T_355a8_row2_col2,#T_355a8_row2_col3,#T_355a8_row2_col7,#T_355a8_row3_col0,#T_355a8_row3_col3,#T_355a8_row3_col4,#T_355a8_row3_col5,#T_355a8_row3_col7,#T_355a8_row4_col0,#T_355a8_row4_col2,#T_355a8_row4_col3,#T_355a8_row4_col4,#T_355a8_row4_col7,#T_355a8_row5_col3,#T_355a8_row5_col4,#T_355a8_row5_col7,#T_355a8_row6_col0,#T_355a8_row6_col1,#T_355a8_row6_col2,#T_355a8_row6_col3,#T_355a8_row6_col4,#T_355a8_row6_col7,#T_355a8_row7_col0,#T_355a8_row7_col3,#T_355a8_row7_col4,#T_355a8_row7_col7,#T_355a8_row8_col0,#T_355a8_row8_col3,#T_355a8_row8_col4,#T_355a8_row8_col6,#T_355a8_row8_col7,#T_355a8_row9_col3,#T_355a8_row9_col4,#T_355a8_row9_col6,#T_355a8_row9_col7,#T_355a8_row10_col0,#T_355a8_row10_col3,#T_355a8_row10_col4,#T_355a8_row10_col7,#T_355a8_row11_col3,#T_355a8_row11_col4,#T_355a8_row11_col5,#T_355a8_row11_col7,#T_355a8_row12_col0,#T_355a8_row12_col2,#T_355a8_row12_col3,#T_355a8_row12_col4,#T_355a8_row12_col7,#T_355a8_row13_col0,#T_355a8_row13_col3,#T_355a8_row13_col4,#T_355a8_row13_col5,#T_355a8_row13_col7,#T_355a8_row14_col0,#T_355a8_row14_col1,#T_355a8_row14_col2,#T_355a8_row14_col3,#T_355a8_row14_col4,#T_355a8_row14_col7{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_355a8_row0_col4,#T_355a8_row5_col0,#T_355a8_row5_col5,#T_355a8_row9_col2,#T_355a8_row9_col5,#T_355a8_row10_col2,#T_355a8_row11_col0,#T_355a8_row11_col2,#T_355a8_row12_col1{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_355a8_row0_col5{
#             background-color:  #ede7f2;
#             color:  #000000;
#         }#T_355a8_row0_col6,#T_355a8_row3_col8{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_355a8_row0_col8{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_355a8_row1_col1,#T_355a8_row7_col2,#T_355a8_row7_col5,#T_355a8_row8_col5,#T_355a8_row10_col1,#T_355a8_row10_col5,#T_355a8_row13_col6{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_355a8_row1_col2,#T_355a8_row4_col6{
#             background-color:  #f6eff7;
#             color:  #000000;
#         }#T_355a8_row1_col4,#T_355a8_row1_col7,#T_355a8_row5_col6,#T_355a8_row8_col2,#T_355a8_row14_col5{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_355a8_row1_col5,#T_355a8_row2_col4,#T_355a8_row3_col1,#T_355a8_row5_col1,#T_355a8_row5_col2,#T_355a8_row6_col6,#T_355a8_row7_col1,#T_355a8_row9_col1{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_355a8_row1_col6{
#             background-color:  #e2dfee;
#             color:  #000000;
#         }#T_355a8_row1_col8{
#             background-color:  #bbc7e0;
#             color:  #000000;
#         }#T_355a8_row2_col5,#T_355a8_row8_col1,#T_355a8_row12_col8{
#             background-color:  #f4eef6;
#             color:  #000000;
#         }#T_355a8_row2_col6,#T_355a8_row13_col8{
#             background-color:  #f5eef6;
#             color:  #000000;
#         }#T_355a8_row2_col8{
#             background-color:  #dddbec;
#             color:  #000000;
#         }#T_355a8_row3_col2,#T_355a8_row10_col8,#T_355a8_row11_col8{
#             background-color:  #f4edf6;
#             color:  #000000;
#         }#T_355a8_row3_col6,#T_355a8_row9_col0,#T_355a8_row13_col2{
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }#T_355a8_row4_col1,#T_355a8_row11_col6{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_355a8_row4_col5,#T_355a8_row7_col6,#T_355a8_row12_col6{
#             background-color:  #fbf4f9;
#             color:  #000000;
#         }#T_355a8_row4_col8,#T_355a8_row5_col8{
#             background-color:  #ede8f3;
#             color:  #000000;
#         }#T_355a8_row6_col5,#T_355a8_row14_col8{
#             background-color:  #f5eff6;
#             color:  #000000;
#         }#T_355a8_row6_col8{
#             background-color:  #eee9f3;
#             color:  #000000;
#         }#T_355a8_row7_col8{
#             background-color:  #efe9f3;
#             color:  #000000;
#         }#T_355a8_row8_col8{
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }#T_355a8_row9_col8{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_355a8_row10_col6{
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }#T_355a8_row14_col6{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }</style><table id="T_355a8_" ><thead>    <tr>        <th class="index_name level0" >profession_type</th>        <th class="col_heading level0 col0" colspan="4">data_analyst</th>        <th class="col_heading level0 col4" colspan="4">system_analyst</th>        <th class="col_heading level0 col8" >All</th>    </tr>    <tr>        <th class="index_name level1" >experience</th>        <th class="col_heading level1 col0" >Junior (no experince)</th>        <th class="col_heading level1 col1" >Junior+ (1-3 years)</th>        <th class="col_heading level1 col2" >Middle (3-6 years)</th>        <th class="col_heading level1 col3" >Senior (6+ years)</th>        <th class="col_heading level1 col4" >Junior (no experince)</th>        <th class="col_heading level1 col5" >Junior+ (1-3 years)</th>        <th class="col_heading level1 col6" >Middle (3-6 years)</th>        <th class="col_heading level1 col7" >Senior (6+ years)</th>        <th class="col_heading level1 col8" ></th>    </tr>    <tr>        <th class="index_name level0" >employer</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_355a8_level0_row0" class="row_heading level0 row0" >СБЕР</th>
#                         <td id="T_355a8_row0_col0" class="data row0 col0" >13</td>
#                         <td id="T_355a8_row0_col1" class="data row0 col1" >159</td>
#                         <td id="T_355a8_row0_col2" class="data row0 col2" >71</td>
#                         <td id="T_355a8_row0_col3" class="data row0 col3" >0</td>
#                         <td id="T_355a8_row0_col4" class="data row0 col4" >2</td>
#                         <td id="T_355a8_row0_col5" class="data row0 col5" >42</td>
#                         <td id="T_355a8_row0_col6" class="data row0 col6" >51</td>
#                         <td id="T_355a8_row0_col7" class="data row0 col7" >0</td>
#                         <td id="T_355a8_row0_col8" class="data row0 col8" >338</td>
#             </tr>
#             <tr>
#                         <th id="T_355a8_level0_row1" class="row_heading level0 row1" >Т1</th>
#                         <td id="T_355a8_row1_col0" class="data row1 col0" >0</td>
#                         <td id="T_355a8_row1_col1" class="data row1 col1" >5</td>
#                         <td id="T_355a8_row1_col2" class="data row1 col2" >21</td>
#                         <td id="T_355a8_row1_col3" class="data row1 col3" >0</td>
#                         <td id="T_355a8_row1_col4" class="data row1 col4" >3</td>
#                         <td id="T_355a8_row1_col5" class="data row1 col5" >17</td>
#                         <td id="T_355a8_row1_col6" class="data row1 col6" >57</td>
#                         <td id="T_355a8_row1_col7" class="data row1 col7" >3</td>
#                         <td id="T_355a8_row1_col8" class="data r

# %% [markdown]
# <div style="border:solid green 1px; padding: 10px">
# Вывод:  ТОП-15 работодателей это компании  следующих отраслей: банки, IT, маркетплейсы, ритейл, коммуникации. Лидером по количеству размещенных вакансий обоих типов является Сбер.

# %% [markdown]
# Посчитаем какая доля вакансий размещена компаниями банковского сектора

# %%
# выделим работодателей банковского сектора
def f_categorize_employer(row):
    if 'банк' in row or 'Банк' in row or 'СБЕР' in row:
        return 'finance'
    else:
        pass
        
finance_sector = hh_data['employer'].apply(f_categorize_employer).tolist() # применим функцию с полю 'employer'

# считаем количество компаний в категории банковский сектор
finance_sector_count=[]
for i in finance_sector:
    if i=='finance':
        finance_sector_count.append(i)

print(f'Доля вакансий, размещенная компаниями банковского сектора: {len(finance_sector_count)/len(finance_sector)*100}')
# Out:
# Доля вакансий, размещенная компаниями банковского сектора: 17.330462863293864

# %% [markdown]
# <a id="cell3.4"></a>
# ### Анализ вакансий по формату работы и типу занятости

# %%
# количество вакансий в разбивке по формату работы
hh_data.pivot_table(
    index='schedule',
    columns=['profession_type','experience'],
    values='name',
    aggfunc='count',
    margins=True
).sort_values('All', ascending=False).fillna(0).query('schedule != "All"').astype(int)\
.style.background_gradient(axis=None)
# Out:
# <style  type="text/css" >
# #T_40602_row0_col0,#T_40602_row1_col2{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_40602_row0_col1{
#             background-color:  #b1c2de;
#             color:  #000000;
#         }#T_40602_row0_col2{
#             background-color:  #e6e2ef;
#             color:  #000000;
#         }#T_40602_row0_col3,#T_40602_row1_col3,#T_40602_row2_col0,#T_40602_row2_col3,#T_40602_row2_col4,#T_40602_row2_col7,#T_40602_row3_col0,#T_40602_row3_col1,#T_40602_row3_col2,#T_40602_row3_col3,#T_40602_row3_col4,#T_40602_row3_col5,#T_40602_row3_col6,#T_40602_row3_col7,#T_40602_row3_col8{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_40602_row0_col4,#T_40602_row2_col5{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_40602_row0_col5{
#             background-color:  #d9d8ea;
#             color:  #000000;
#         }#T_40602_row0_col6{
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }#T_40602_row0_col7,#T_40602_row1_col4,#T_40602_row2_col1{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_40602_row0_col8{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_40602_row1_col0,#T_40602_row1_col7,#T_40602_row2_col2,#T_40602_row2_col6{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_40602_row1_col1{
#             background-color:  #f6eff7;
#             color:  #000000;
#         }#T_40602_row1_col5{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_40602_row1_col6{
#             background-color:  #ebe6f2;
#             color:  #000000;
#         }#T_40602_row1_col8{
#             background-color:  #abbfdc;
#             color:  #000000;
#         }#T_40602_row2_col8{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }</style><table id="T_40602_" ><thead>    <tr>        <th class="index_name level0" >profession_type</th>        <th class="col_heading level0 col0" colspan="4">data_analyst</th>        <th class="col_heading level0 col4" colspan="4">system_analyst</th>        <th class="col_heading level0 col8" >All</th>    </tr>    <tr>        <th class="index_name level1" >experience</th>        <th class="col_heading level1 col0" >Junior (no experince)</th>        <th class="col_heading level1 col1" >Junior+ (1-3 years)</th>        <th class="col_heading level1 col2" >Middle (3-6 years)</th>        <th class="col_heading level1 col3" >Senior (6+ years)</th>        <th class="col_heading level1 col4" >Junior (no experince)</th>        <th class="col_heading level1 col5" >Junior+ (1-3 years)</th>        <th class="col_heading level1 col6" >Middle (3-6 years)</th>        <th class="col_heading level1 col7" >Senior (6+ years)</th>        <th class="col_heading level1 col8" ></th>    </tr>    <tr>        <th class="index_name level0" >schedule</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_40602_level0_row0" class="row_heading level0 row0" >Полный день</th>
#                         <td id="T_40602_row0_col0" class="data row0 col0" >122</td>
#                         <td id="T_40602_row0_col1" class="data row0 col1" >905</td>
#                         <td id="T_40602_row0_col2" class="data row0 col2" >406</td>
#                         <td id="T_40602_row0_col3" class="data row0 col3" >8</td>
#                         <td id="T_40602_row0_col4" class="data row0 col4" >51</td>
#                         <td id="T_40602_row0_col5" class="data row0 col5" >553</td>
#                         <td id="T_40602_row0_col6" class="data row0 col6" >574</td>
#                         <td id="T_40602_row0_col7" class="data row0 col7" >25</td>
#                         <td id="T_40602_row0_col8" class="data row0 col8" >2644</td>
#             </tr>
#             <tr>
#                         <th id="T_40602_level0_row1" class="row_heading level0 row1" >Удаленная работа</th>
#                         <td id="T_40602_row1_col0" class="data row1 col0" >15</td>
#                         <td id="T_40602_row1_col1" class="data row1 col1" >158</td>
#                         <td id="T_40602_row1_col2" class="data row1 col2" >132</td>
#                         <td id="T_40602_row1_col3" class="data row1 col3" >5</td>
#                         <td id="T_40602_row1_col4" class="data row1 col4" >29</td>
#                         <td id="T_40602_row1_col5" class="data row1 col5" >263</td>
#                         <td id="T_40602_row1_col6" class="data row1 col6" >341</td>
#                         <td id="T_40602_row1_col7" class="data row1 col7" >17</td>
#                         <td id="T_40602_row1_col8" class="data row1 col8" >960</td>
#             </tr>
#             <tr>
#                         <th id="T_40602_level0_row2" class="row_heading level0 row2" >Гибкий график</th>
#                         <td id="T_40602_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_40602_row2_col1" class="data row2 col1" >21</td>
#                         <td id="T_40602_row2_col2" class="data row2 col2" >17</td>
#                         <td id="T_40602_row2_col3" class="data row2 col3" >0</td>
#                         <td id="T_40602_row2_col4" class="data row2 col4" >6</td>
#                         <td id="T_40602_row2_col5" class="data row2 col5" >36</td>
#                         <td id="T_40602_row2_col6" class="data row2 col6" >17</td>
#                         <td id="T_40602_row2_col7" class="data row2 col7" >2</td>
#                         <td id="T_40602_row2_col8" class="data row2 col8" >102</td>
#             </tr>
#             <tr>
#                         <th id="T_40602_level0_row3" class="row_heading level0 row3" >Сменный график</th>
#                         <td id="T_40602_row3_col0" class="data row3 col0" >2</td>
#                         <td id="T_40602_row3_col1" class="data row3 col1" >7</td>
#                         <td id="T_40602_row3_col2" class="data row3 col2" >0</td>
#                         <td id="T_40602_row3_col3" class="data row3 col3" >0</td>
#                         <td id="T_40602_row3_col4" class="data row3 col4" >0</td>
#                         <td id="T_40602_row3_col5" class="data row3 col5" >0</td>
#                         <td id="T_40602_row3_col6" class="data row3 col6" >1</td>
#                         <td id="T_40602_row3_col7" class="data row3 col7" >0</td>
#                         <td id="T_40602_row3_col8" class="data row3 col8" >10</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# <div style="border:solid green 1px; padding: 10px">
# Вывод: для обоих типов вакансий на всех грейдах лидирует формат - полный день. Почти 17% вакансий дата-аналитиков предлагают удаленную работу , у системных аналитиков удаленная работа более распространена - 34% всех вакансий, что обусловлено спецификой работы

# %%
# количество вакансий в разбивке по типу занятости 
hh_data.pivot_table(
    index='employment',
    columns=['profession_type','experience'],
    values='name',
    aggfunc='count',
    margins=True
).sort_values('All', ascending=False).fillna(0).query('employment != "All"').astype(int)\
.style.background_gradient(axis=None)
# Out:
# <style  type="text/css" >
# #T_318d8_row0_col0{
#             background-color:  #faf3f9;
#             color:  #000000;
#         }#T_318d8_row0_col1{
#             background-color:  #c1cae2;
#             color:  #000000;
#         }#T_318d8_row0_col2{
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }#T_318d8_row0_col3,#T_318d8_row1_col1,#T_318d8_row1_col2,#T_318d8_row1_col3,#T_318d8_row1_col5,#T_318d8_row1_col6,#T_318d8_row1_col7,#T_318d8_row2_col0,#T_318d8_row2_col1,#T_318d8_row2_col2,#T_318d8_row2_col3,#T_318d8_row2_col4,#T_318d8_row2_col5,#T_318d8_row2_col6,#T_318d8_row2_col7,#T_318d8_row3_col0,#T_318d8_row3_col1,#T_318d8_row3_col2,#T_318d8_row3_col3,#T_318d8_row3_col4,#T_318d8_row3_col5,#T_318d8_row3_col6,#T_318d8_row3_col7,#T_318d8_row3_col8{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }#T_318d8_row0_col4,#T_318d8_row0_col7,#T_318d8_row1_col8{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_318d8_row0_col5{
#             background-color:  #d4d4e8;
#             color:  #000000;
#         }#T_318d8_row0_col6{
#             background-color:  #ced0e6;
#             color:  #000000;
#         }#T_318d8_row0_col8{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_318d8_row1_col0,#T_318d8_row2_col8{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_318d8_row1_col4{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }</style><table id="T_318d8_" ><thead>    <tr>        <th class="index_name level0" >profession_type</th>        <th class="col_heading level0 col0" colspan="4">data_analyst</th>        <th class="col_heading level0 col4" colspan="4">system_analyst</th>        <th class="col_heading level0 col8" >All</th>    </tr>    <tr>        <th class="index_name level1" >experience</th>        <th class="col_heading level1 col0" >Junior (no experince)</th>        <th class="col_heading level1 col1" >Junior+ (1-3 years)</th>        <th class="col_heading level1 col2" >Middle (3-6 years)</th>        <th class="col_heading level1 col3" >Senior (6+ years)</th>        <th class="col_heading level1 col4" >Junior (no experince)</th>        <th class="col_heading level1 col5" >Junior+ (1-3 years)</th>        <th class="col_heading level1 col6" >Middle (3-6 years)</th>        <th class="col_heading level1 col7" >Senior (6+ years)</th>        <th class="col_heading level1 col8" ></th>    </tr>    <tr>        <th class="index_name level0" >employment</th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_318d8_level0_row0" class="row_heading level0 row0" >Полная занятость</th>
#                         <td id="T_318d8_row0_col0" class="data row0 col0" >123</td>
#                         <td id="T_318d8_row0_col1" class="data row0 col1" >1079</td>
#                         <td id="T_318d8_row0_col2" class="data row0 col2" >549</td>
#                         <td id="T_318d8_row0_col3" class="data row0 col3" >13</td>
#                         <td id="T_318d8_row0_col4" class="data row0 col4" >56</td>
#                         <td id="T_318d8_row0_col5" class="data row0 col5" >851</td>
#                         <td id="T_318d8_row0_col6" class="data row0 col6" >926</td>
#                         <td id="T_318d8_row0_col7" class="data row0 col7" >44</td>
#                         <td id="T_318d8_row0_col8" class="data row0 col8" >3641</td>
#             </tr>
#             <tr>
#                         <th id="T_318d8_level0_row1" class="row_heading level0 row1" >Стажировка</th>
#                         <td id="T_318d8_row1_col0" class="data row1 col0" >15</td>
#                         <td id="T_318d8_row1_col1" class="data row1 col1" >1</td>
#                         <td id="T_318d8_row1_col2" class="data row1 col2" >0</td>
#                         <td id="T_318d8_row1_col3" class="data row1 col3" >0</td>
#                         <td id="T_318d8_row1_col4" class="data row1 col4" >29</td>
#                         <td id="T_318d8_row1_col5" class="data row1 col5" >0</td>
#                         <td id="T_318d8_row1_col6" class="data row1 col6" >0</td>
#                         <td id="T_318d8_row1_col7" class="data row1 col7" >0</td>
#                         <td id="T_318d8_row1_col8" class="data row1 col8" >45</td>
#             </tr>
#             <tr>
#                         <th id="T_318d8_level0_row2" class="row_heading level0 row2" >Частичная занятость</th>
#                         <td id="T_318d8_row2_col0" class="data row2 col0" >3</td>
#                         <td id="T_318d8_row2_col1" class="data row2 col1" >8</td>
#                         <td id="T_318d8_row2_col2" class="data row2 col2" >5</td>
#                         <td id="T_318d8_row2_col3" class="data row2 col3" >0</td>
#                         <td id="T_318d8_row2_col4" class="data row2 col4" >1</td>
#                         <td id="T_318d8_row2_col5" class="data row2 col5" >0</td>
#                         <td id="T_318d8_row2_col6" class="data row2 col6" >5</td>
#                         <td id="T_318d8_row2_col7" class="data row2 col7" >0</td>
#                         <td id="T_318d8_row2_col8" class="data row2 col8" >22</td>
#             </tr>
#             <tr>
#                         <th id="T_318d8_level0_row3" class="row_heading level0 row3" >Проектная работа</th>
#                         <td id="T_318d8_row3_col0" class="data row3 col0" >1</td>
#                         <td id="T_318d8_row3_col1" class="data row3 col1" >3</td>
#                         <td id="T_318d8_row3_col2" class="data row3 col2" >1</td>
#                         <td id="T_318d8_row3_col3" class="data row3 col3" >0</td>
#                         <td id="T_318d8_row3_col4" class="data row3 col4" >0</td>
#                         <td id="T_318d8_row3_col5" class="data row3 col5" >1</td>
#                         <td id="T_318d8_row3_col6" class="data row3 col6" >2</td>
#                         <td id="T_318d8_row3_col7" class="data row3 col7" >0</td>
#                         <td id="T_318d8_row3_col8" class="data row3 col8" >8</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# <div style="border:solid green 1px; padding: 10px">
# Вывод: почти все вакансии предполагают полную занятость. Есть несколько вакансий стажировок. Отдельно посмотрим, какие компании предлагают стажировку

# %% [markdown]
# Компании, предлагающие стажировку

# %%
intern = hh_data.loc[hh_data['employment']=='Стажировка']
intern.pivot_table(
    columns = 'profession_type',
    index='employer',
    values='name',
    aggfunc='count',
    margins=True
).sort_values('All', ascending=False).fillna(0).query('employer != "All"').astype(int)
# Out:
# profession_type                                 data_analyst  system_analyst  \
# employer
# Aston                                                      0              16
# Автомакон                                                  2               1
# Центр финансовых технологий                                0               3
# Ozon                                                       2               1
# IBS                                                        0               2
# Дунайс                                                     0               2
# Юникон АП                                                  2               0
# Эр-1                                                       2               0
# СИБУР, Группа компаний                                     2               0
# Т1                                                         0               1
# ЦРПТ (Центр развития перспективных технологий)             1               0
# Феникс образование                                         0               1
# СБЕР                                                       1               0
# Changellenge                                               1               0
# ППК Фонд развития территорий                               1               0
# МТС                                                        0               1
# Компания CADesign                                          1               0
# Ингруппа                                                   0               1
# Платформа Третье Мнение                                    1               0
#
# profession_type                                 All
# employer
# Aston                                            16
# Автомакон                                         3
# Центр финансовых технологий                       3
# Ozon                                              3
# IBS                                               2
# Дунайс                                            2
# Юникон АП                                         2
# Эр-1                                              2
# СИБУР, Группа компаний                            2
# Т1                                                1
# ЦРПТ (Центр развития перспективных технологий)    1
# Феникс образование                                1
# СБЕР                                              1
# Changellenge                                      1
# ППК Фонд развития территорий                      1
# МТС                                               1
# Компания CADesign                                 1
# Ингруппа                                          1
# Платформа Третье Мнение                           1

# %% [markdown]
# <div style="border:solid green 1px; padding: 10px">
# Вывод: безусловным лидером по количеству вакансий-стажировок является Aston (российская ИТ-компания). В основном стажировки предлагают специализированные ИТ-компании и бигтех

# %% [markdown]
# <a id="cell3.5"></a>
# ### Анализ уровня предлагаемой оплаты

# %%
#функция расчета границ зарплаты в разбивке по грейдам
def func_salary_by_exp(df):
        result_from = df.groupby(['profession_type','experience'])['salary_from'].agg(['median','mean']).round(0).reset_index()
        result_to = df.groupby(['profession_type','experience'])['salary_to'].agg(['median','mean']).round(0).reset_index()
        result = result_from.merge(result_to, on=['profession_type','experience'], how='left').\
                rename(columns = {'median_x':'median_salary_from',
                                  'mean_x':'mean_salary_from',
                                  'median_y':'median_salary_to',
                                  'mean_y':'mean_salary_to'})
        return result

data_salary = func_salary_by_exp(hh_data)
data_salary
# Out:
#   profession_type             experience  median_salary_from  \
# 0    data_analyst  Junior (no experince)             60000.0
# 1    data_analyst    Junior+ (1-3 years)             90000.0
# 2    data_analyst     Middle (3-6 years)            150000.0
# 3    data_analyst      Senior (6+ years)            200000.0
# 4  system_analyst  Junior (no experince)             70000.0
# 5  system_analyst    Junior+ (1-3 years)            120000.0
# 6  system_analyst     Middle (3-6 years)            200000.0
# 7  system_analyst      Senior (6+ years)            200000.0
#
#    mean_salary_from  median_salary_to  mean_salary_to
# 0           64702.0           80000.0         73331.0
# 1           98010.0          120000.0        129879.0
# 2          173963.0          234000.0        247370.0
# 3          156667.0          240000.0        240000.0
# 4           65161.0           80000.0         97074.0
# 5          131703.0          172000.0        183605.0
# 6          207499.0          295000.0        283616.0
# 7          206698.0          340000.0        362857.0

# %%
#диаграммa распределения границ зарплат по грейдам
sns.barplot(data = data_salary, x = 'experience', y = 'median_salary_from', hue = 'profession_type')
plt.title('Медиана зарплат в зависимости от грейда')
plt.ylabel('median_salary, RUB')
plt.yticks(np.arange(0, 250000, step=20000))
plt.xticks(rotation=45)
plt.grid()
plt.show()

# %% [markdown]
# <div style="border:solid green 1px; padding: 10px">
# Вывод:
#
# - данные по зарплате редко публикуются для обоих типов вакансий
# - в среднем дата-аналитикам предлагают меньше зарплату, чем сисетмным аналитикам на всех грейдах
# - зарплата в прямой зависимости от грейда (чем выше грейд, тем больше зарплата)
# - большая разница зарплат между грейдами : разница между junior и senior-специалистами  более чем 3 раза
# - следует отметить, что уровень зарплат может сильно отличаться по регионам

# %% [markdown]
# <a id="cell4"></a>
# ## Общий вывод:

# %% [markdown]
# <div style="border:solid green 1px; padding: 10px">
#
# В рамках исследования проанализированы данные по вакансиям из API HH.ru за первое полугодие 2024г:
# 1. Выгружены данные, выполнена их предобработка (проверка/обработка/исправление пропусков, дубликатов, форматов данных), объединение данных по типам вакансий в один датасет
# 2. Проведен исследовательский анализ, по результатам которого можно сделать следующие выводы:
#
# Навыки:
# В описаниях вакансий  большую часть требований (более 85%) составляют hard навыки, т.о. специальности дата и системного аналитика требуют больше технических компетенций, чем soft навыков, особенно на начальных и средних позициях.
# Нard-навыки почти одинаковы для всех грейдов. Наиболее востребованные hard-навыки для дата аналитиков:  sql, python, pandas, анализ данных, документация. Наиболее востребованные hard-навыки для системных аналитиков:  документация, bpmn, sql, confluence, системный анализ.
# Soft-навыки идентичны для обоих типов специальностей (дата и системный аналитик) и также  идентичны для всех грейдов. Наиболее востребованные soft-навыки: аналитическое мышление, работа с большим объемом информации, коммуникация.
#
# Опыт работы:
# Наиболее востребованы специалисты c опытом работы: уровня Junior+(с опытом 1-3 года) и Middle. При этом  у дата-аналитиков более востребованы специалисты Junior+, а у системных аналитиков более востребованы специалисты Middle.  Начинающим дата-аналитикам будет проще найти вакансию.
# Специалисты без опыта мало востребованы на рынке труда (6% всех размещенных вакансий). Вакансии для специалистов без опыта (в т.ч. стажировки) в основном размещают специализированные ИТ-компании и крупные технологические компании (бигтех). Следует отметить очень низкое предложение вакансий обоих типов для Senior специалистов (1.5% всех размещенных вакансий). Возможно, это связано с тем, что  HH.ru  - площадка, более ориентированная на специалистов массовых сегментов, а Senior специалисты используют другие, более узко специализированные площадки.
#
# Формат работы:
# Для обоих типов вакансий на всех грейдах лидирует формат - полный день. Почти 17% вакансий дата-аналитиков предлагают удаленную работу, у системных аналитиков удаленная работа более распространена - 34% всех вакансий, что обусловлено спецификой работы.
# Почти все вакансии предполагают полную занятость. У некоторых компаний есть варианты стажировок. Безусловным лидером по количеству вакансий-стажировок является Aston (российская ИТ-компания). В основном стажировки предлагают специализированные ИТ-компании и бигтех.
#
# Регионы:
# Москва с существенным отрывом лидирует по числу размещенных вакансий обоих типов (почти 65% всех размещенных вакансий), на втором месте - СПб (примерно 10% всех вакансий), в ТОП-5 также входят другие города-миллионники (Екатеринбург, Новосибирск, Казань, Н.Новгород), на эти 4 города в совокупности приходится порядка 9% вакансий.
#
# Работодатели
# ТОП-15 работодателей это компании  следующих отраслей: банки, IT, маркетплейсы, ритейл, коммуникации. Лидером по количеству размещенных вакансий обоих типов (дата-аналитик и системный аналитик) является Сбер. В целом на банковский сектор  приходится примерно 17% размещаемых вакансий*
#
# Зарплата
#  : Данные по зарплате редко публикуются для обоих типов вакансий. Зарплата зависит от грейда и очень диверсифицирована между грейдами : разница между junior и senior-специалистами более чем 3 раза. Следует отметить, что уровень зарплат может сильно отличаться по регионам.
